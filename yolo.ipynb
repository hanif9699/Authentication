# %% [markdown]
# <a href="https://colab.research.google.com/github/hanif9699/Authentication/blob/master/yolo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get update
# Out:
# Ign:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:3 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:4 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Ign:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [564 B]
# Get:7 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release [564 B]
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [801 B]
# Get:10 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release.gpg [801 B]
# Get:11 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ InRelease [3,609 B]
# Get:12 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic InRelease [15.4 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:14 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages [64.9 kB]
# Get:15 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Packages [5,867 B]
# Get:16 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main Sources [1,613 kB]
# Get:17 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [345 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [943 kB]
# Get:19 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [156 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [691 kB]
# Get:21 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 Packages [774 kB]
# Fetched 4,866 kB in 4s (1,178 kB/s)
# Reading package lists... Done

# %%
# !apt-get upgrade
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Calculating upgrade... Done
# The following packages have been kept back:
#   libcudnn7 libcudnn7-dev
# The following packages will be upgraded:
#   base-files cuda-compat-10-0 e2fsprogs libcom-err2 libext2fs2 libss2
#   linux-libc-dev tar
# 8 upgraded, 0 newly installed, 0 to remove and 2 not upgraded.
# Need to get 8,328 kB of archives.
# After this operation, 47.1 kB of additional disk space will be used.
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-compat-10-0 410.79-1 [6,466 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 base-files amd64 10.1ubuntu2.4 [60.2 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libext2fs2 amd64 1.44.1-1ubuntu1.1 [157 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 e2fsprogs amd64 1.44.1-1ubuntu1.1 [390 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 tar amd64 1.29b-2ubuntu0.1 [234 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcom-err2 amd64 1.44.1-1ubuntu1.1 [9,228 B]
# Get:7 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libss2 amd64 1.44.1-1ubuntu1.1 [11.1 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 linux-libc-dev amd64 4.15.0-45.48 [1,001 kB]
# Fetched 8,328 kB in 1s (7,915 kB/s)
# (Reading database ... 131322 files and directories currently installed.)
# Preparing to unpack .../base-files_10.1ubuntu2.4_amd64.deb ...
# Unpacking base-files (10.1ubuntu2.4) over (10.1ubuntu2.3) ...
# Setting up base-files (10.1ubuntu2.4) ...
# Installing new version of config file /etc/issue ...
# Installing new version of config file /etc/issue.net ...
# Installing new version of config file /etc/lsb-release ...
# (Reading database ... 131322 files and directories currently installed.)
# Preparing to unpack .../libext2fs2_1.44.1-1ubuntu1.1_amd64.deb ...
# Unpacking libext2fs2:amd64 (1.44.1-1ubuntu1.1) over (1.44.1-1ubuntu1) ...
# Setting up libext2fs2:amd64 (1.44.1-1ubuntu1.1) ...
# (Reading database ... 131322 files and directories currently installed.)
# Preparing to unpack .../e2fsprogs_1.44.1-1ubuntu1.1_amd64.deb ...
# Unpacking e2fsprogs (1.44.1-1ubuntu1.1) over (1.44.1-1ubuntu1) ...
# Setting up e2fsprogs (1.44.1-1ubuntu1.1) ...
# (Reading database ... 131322 files and directories currently installed.)
# Preparing to unpack .../tar_1.29b-2ubuntu0.1_amd64.deb ...
# Unpacking tar (1.29b-2ubuntu0.1) over (1.29b-2) ...
# Setting up tar (1.29b-2ubuntu0.1) ...
# update-alternatives: warning: forcing reinstallation of alternative /usr/sbin/rmt-tar because link group rmt is broken
# (Reading database ... 131322 files and directories currently installed.)
# Preparing to unpack .../libcom-err2_1.44.1-1ubuntu1.1_amd64.deb ...
# Unpacking libcom-err2:amd64 (1.44.1-1ubuntu1.1) over (1.44.1-1ubuntu1) ...
# Setting up libcom-err2:amd64 (1.44.1-1ubuntu1.1) ...
# (Reading database ... 131322 files and directories currently installed.)
# Preparing to unpack .../libss2_1.44.1-1ubuntu1.1_amd64.deb ...
# Unpacking libss2:amd64 (1.44.1-1ubuntu1.1) over (1.44.1-1ubuntu1) ...
# Setting up libss2:amd64 (1.44.1-1ubuntu1.1) ...
# (Reading database ... 131322 files and directories currently installed.)
# Preparing to unpack .../cuda-compat-10-0_410.79-1_amd64.deb ...
# Unpacking cuda-compat-10-0 (410.79-1) over (410.48-1) ...
# Preparing to unpack .../linux-libc-dev_4.15.0-45.48_amd64.deb ...
# Unpacking linux-libc-dev:amd64 (4.15.0-45.48) over (4.15.0-44.47) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Setting up linux-libc-dev:amd64 (4.15.0-45.48) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Setting up cuda-compat-10-0 (410.79-1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...

# %%
# !ln -sf /opt/bin/nvidia-smi /usr/bin/nvidia-smi
# !pip install gputil
# !pip install psutil
# !pip install humanize
import psutil
import humanize
import os
import GPUtil as GPU
GPUs = GPU.getGPUs()
# XXX: only one GPU on Colab and isn’t guaranteed
gpu = GPUs[0]
def printm():
 process = psutil.Process(os.getpid())                                                 
 print("Gen RAM Free: " + humanize.naturalsize( psutil.virtual_memory().available ), " | Proc size: " + humanize.naturalsize( process.memory_info().rss))
 print("GPU RAM Free: {0:.0f}MB | Used: {1:.0f}MB | Util {2:3.0f}% | Total {3:.0f}MB".format(gpu.memoryFree, gpu.memoryUsed, gpu.memoryUtil*100, gpu.memoryTotal))
printm()
# Out:
# Collecting gputil
#   Downloading https://files.pythonhosted.org/packages/ed/0e/5c61eedde9f6c87713e89d794f01e378cfd9565847d4576fa627d758c554/GPUtil-1.4.0.tar.gz
# Building wheels for collected packages: gputil
#   Building wheel for gputil (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/3d/77/07/80562de4bb0786e5ea186911a2c831fdd0018bda69beab71fd
# Successfully built gputil
# Installing collected packages: gputil
# Successfully installed gputil-1.4.0
# Requirement already satisfied: psutil in /usr/local/lib/python3.6/dist-packages (5.4.8)
# Requirement already satisfied: humanize in /usr/local/lib/python3.6/dist-packages (0.5.1)
# Gen RAM Free: 12.9 GB  | Proc size: 142.5 MB
# GPU RAM Free: 11441MB | Used: 0MB | Util   0% | Total 11441MB

# %%
# !apt-get install build-essential
# !apt-get install cmake git libgtk2.0-dev pkg-config libavcodec-dev libavformat-dev libswscale-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# build-essential is already the newest version (12.4ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 2 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# cmake is already the newest version (3.10.2-1ubuntu2).
# pkg-config is already the newest version (0.29.1-0ubuntu2).
# git is already the newest version (1:2.17.1-1ubuntu0.4).
# libavcodec-dev is already the newest version (7:3.4.4-0ubuntu0.18.04.1).
# libavcodec-dev set to manually installed.
# libavformat-dev is already the newest version (7:3.4.4-0ubuntu0.18.04.1).
# libavformat-dev set to manually installed.
# libswscale-dev is already the newest version (7:3.4.4-0ubuntu0.18.04.1).
# libswscale-dev set to manually installed.
# The following additional packages will be installed:
#   autoconf automake autopoint autotools-dev debhelper dh-autoreconf
#   dh-strip-nondeterminism file gettext gettext-base gir1.2-atk-1.0
#   gir1.2-freedesktop gir1.2-gdkpixbuf-2.0 gir1.2-gtk-2.0 gir1.2-pango-1.0
#   intltool-debian libarchive-cpio-perl libarchive-zip-perl libatk1.0-dev
#   libcairo-script-interpreter2 libcairo2-dev libfile-stripnondeterminism-perl
#   libgail-common libgail18 libgdk-pixbuf2.0-dev libgtk2.0-0 libgtk2.0-bin
#   libgtk2.0-common libmagic-mgc libmagic1 libmail-sendmail-perl
#   libpango1.0-dev libpangoxft-1.0-0 libpixman-1-dev libsigsegv2
#   libsys-hostname-long-perl libtimedate-perl libtool libxcb-shm0-dev
#   libxcomposite-dev libxcursor-dev libxinerama-dev libxml2-utils libxrandr-dev
#   m4 po-debconf x11proto-composite-dev x11proto-randr-dev
#   x11proto-xinerama-dev
# Suggested packages:
#   autoconf-archive gnu-standards autoconf-doc dh-make dwz gettext-doc
#   libasprintf-dev libgettextpo-dev libcairo2-doc gvfs libgtk2.0-doc
#   imagemagick libpango1.0-doc libtool-doc gcj-jdk m4-doc libmail-box-perl
# The following NEW packages will be installed:
#   autoconf automake autopoint autotools-dev debhelper dh-autoreconf
#   dh-strip-nondeterminism file gettext gettext-base gir1.2-atk-1.0
#   gir1.2-freedesktop gir1.2-gdkpixbuf-2.0 gir1.2-gtk-2.0 gir1.2-pango-1.0
#   intltool-debian libarchive-cpio-perl libarchive-zip-perl libatk1.0-dev
#   libcairo-script-interpreter2 libcairo2-dev libfile-stripnondeterminism-perl
#   libgail-common libgail18 libgdk-pixbuf2.0-dev libgtk2.0-0 libgtk2.0-bin
#   libgtk2.0-common libgtk2.0-dev libmagic-mgc libmagic1 libmail-sendmail-perl
#   libpango1.0-dev libpangoxft-1.0-0 libpixman-1-dev libsigsegv2
#   libsys-hostname-long-perl libtimedate-perl libtool libxcb-shm0-dev
#   libxcomposite-dev libxcursor-dev libxinerama-dev libxml2-utils libxrandr-dev
#   m4 po-debconf x11proto-composite-dev x11proto-randr-dev
#   x11proto-xinerama-dev
# 0 upgraded, 50 newly installed, 0 to remove and 2 not upgraded.
# Need to get 10.6 MB of archives.
# After this operation, 53.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic-mgc amd64 1:5.32-2ubuntu0.1 [184 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic1 amd64 1:5.32-2ubuntu0.1 [68.4 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 file amd64 1:5.32-2ubuntu0.1 [22.1 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gettext-base amd64 0.19.8.1-6ubuntu0.1 [50.1 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsigsegv2 amd64 2.12-1 [14.7 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/main amd64 m4 amd64 1.4.18-1 [197 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/main amd64 autoconf all 2.69-11 [322 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/main amd64 autotools-dev all 20180224.1 [39.6 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/main amd64 automake all 1:1.15.1-3ubuntu2 [509 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 autopoint all 0.19.8.1-6ubuntu0.1 [412 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtool all 2.4.6-2 [194 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic/main amd64 dh-autoreconf all 17 [15.8 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libarchive-zip-perl all 1.60-1ubuntu0.1 [84.6 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfile-stripnondeterminism-perl all 0.040-1.1~build1 [13.8 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtimedate-perl all 2.3000-2 [37.5 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic/main amd64 dh-strip-nondeterminism all 0.040-1.1~build1 [5,208 B]
# Get:17 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gettext amd64 0.19.8.1-6ubuntu0.1 [894 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic/main amd64 intltool-debian all 0.35.0+20060710.4 [24.9 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic/main amd64 po-debconf all 1.0.20 [232 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 debhelper all 11.1.6ubuntu2 [902 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic/main amd64 gir1.2-atk-1.0 amd64 2.28.1-1 [17.8 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic/main amd64 gir1.2-freedesktop amd64 1.56.1-1 [9,080 B]
# Get:23 http://archive.ubuntu.com/ubuntu bionic/main amd64 gir1.2-gdkpixbuf-2.0 amd64 2.36.11-2 [7,748 B]
# Get:24 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgtk2.0-common all 2.24.32-1ubuntu1 [125 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpangoxft-1.0-0 amd64 1.40.14-1ubuntu0.1 [15.0 kB]
# Get:26 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gir1.2-pango-1.0 amd64 1.40.14-1ubuntu0.1 [21.6 kB]
# Get:27 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgtk2.0-0 amd64 2.24.32-1ubuntu1 [1,769 kB]
# Get:28 http://archive.ubuntu.com/ubuntu bionic/main amd64 gir1.2-gtk-2.0 amd64 2.24.32-1ubuntu1 [172 kB]
# Get:29 http://archive.ubuntu.com/ubuntu bionic/main amd64 libarchive-cpio-perl all 0.10-1 [9,644 B]
# Get:30 http://archive.ubuntu.com/ubuntu bionic/main amd64 libatk1.0-dev amd64 2.28.1-1 [79.9 kB]
# Get:31 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcairo-script-interpreter2 amd64 1.15.10-2ubuntu0.1 [53.5 kB]
# Get:32 http://archive.ubuntu.com/ubuntu bionic/main amd64 libpixman-1-dev amd64 0.34.0-2 [244 kB]
# Get:33 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxcb-shm0-dev amd64 1.13-1 [6,676 B]
# Get:34 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcairo2-dev amd64 1.15.10-2ubuntu0.1 [626 kB]
# Get:35 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgail18 amd64 2.24.32-1ubuntu1 [14.2 kB]
# Get:36 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgail-common amd64 2.24.32-1ubuntu1 [112 kB]
# Get:37 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgdk-pixbuf2.0-dev amd64 2.36.11-2 [46.8 kB]
# Get:38 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgtk2.0-bin amd64 2.24.32-1ubuntu1 [7,536 B]
# Get:39 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpango1.0-dev amd64 1.40.14-1ubuntu0.1 [288 kB]
# Get:40 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-xinerama-dev all 2018.4-4 [2,628 B]
# Get:41 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxinerama-dev amd64 2:1.1.3-1 [8,404 B]
# Get:42 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-randr-dev all 2018.4-4 [2,620 B]
# Get:43 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxrandr-dev amd64 2:1.5.1-1 [24.0 kB]
# Get:44 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxcursor-dev amd64 1:1.1.15-1 [26.5 kB]
# Get:45 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-composite-dev all 1:2018.4-4 [2,620 B]
# Get:46 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxcomposite-dev amd64 1:0.4.4-2 [9,136 B]
# Get:47 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxml2-utils amd64 2.9.4+dfsg1-6.1ubuntu1.2 [35.8 kB]
# Get:48 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgtk2.0-dev amd64 2.24.32-1ubuntu1 [2,652 kB]
# Get:49 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsys-hostname-long-perl all 1.5-1 [11.7 kB]
# Get:50 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmail-sendmail-perl all 0.80-1 [22.6 kB]
# Fetched 10.6 MB in 2s (5,999 kB/s)
# Extracting templates from packages: 100%
# Selecting previously unselected package libmagic-mgc.
# (Reading database ... 131322 files and directories currently installed.)
# Preparing to unpack .../00-libmagic-mgc_1%3a5.32-2ubuntu0.1_amd64.deb ...
# Unpacking libmagic-mgc (1:5.32-2ubuntu0.1) ...
# Selecting previously unselected package libmagic1:amd64.
# Preparing to unpack .../01-libmagic1_1%3a5.32-2ubuntu0.1_amd64.deb ...
# Unpacking libmagic1:amd64 (1:5.32-2ubuntu0.1) ...
# Selecting previously unselected package file.
# Preparing to unpack .../02-file_1%3a5.32-2ubuntu0.1_amd64.deb ...
# Unpacking file (1:5.32-2ubuntu0.1) ...
# Selecting previously unselected package gettext-base.
# Preparing to unpack .../03-gettext-base_0.19.8.1-6ubuntu0.1_amd64.deb ...
# Unpacking gettext-base (0.19.8.1-6ubuntu0.1) ...
# Selecting previously unselected package libsigsegv2:amd64.
# Preparing to unpack .../04-libsigsegv2_2.12-1_amd64.deb ...
# Unpacking libsigsegv2:amd64 (2.12-1) ...
# Selecting previously unselected package m4.
# Preparing to unpack .../05-m4_1.4.18-1_amd64.deb ...
# Unpacking m4 (1.4.18-1) ...
# Selecting previously unselected package autoconf.
# Preparing to unpack .../06-autoconf_2.69-11_all.deb ...
# Unpacking autoconf (2.69-11) ...
# Selecting previously unselected package autotools-dev.
# Preparing to unpack .../07-autotools-dev_20180224.1_all.deb ...
# Unpacking autotools-dev (20180224.1) ...
# Selecting previously unselected package automake.
# Preparing to unpack .../08-automake_1%3a1.15.1-3ubuntu2_all.deb ...
# Unpacking automake (1:1.15.1-3ubuntu2) ...
# Selecting previously unselected package autopoint.
# Preparing to unpack .../09-autopoint_0.19.8.1-6ubuntu0.1_all.deb ...
# Unpacking autopoint (0.19.8.1-6ubuntu0.1) ...
# Selecting previously unselected package libtool.
# Preparing to unpack .../10-libtool_2.4.6-2_all.deb ...
# Unpacking libtool (2.4.6-2) ...
# Selecting previously unselected package dh-autoreconf.
# Preparing to unpack .../11-dh-autoreconf_17_all.deb ...
# Unpacking dh-autoreconf (17) ...
# Selecting previously unselected package libarchive-zip-perl.
# Preparing to unpack .../12-libarchive-zip-perl_1.60-1ubuntu0.1_all.deb ...
# Unpacking libarchive-zip-perl (1.60-1ubuntu0.1) ...
# Selecting previously unselected package libfile-stripnondeterminism-perl.
# Preparing to unpack .../13-libfile-stripnondeterminism-perl_0.040-1.1~build1_all.deb ...
# Unpacking libfile-stripnondeterminism-perl (0.040-1.1~build1) ...
# Selecting previously unselected package libtimedate-perl.
# Preparing to unpack .../14-libtimedate-perl_2.3000-2_all.deb ...
# Unpacking libtimedate-perl (2.3000-2) ...
# Selecting previously unselected package dh-strip-nondeterminism.
# Preparing to unpack .../15-dh-strip-nondeterminism_0.040-1.1~build1_all.deb ...
# Unpacking dh-strip-nondeterminism (0.040-1.1~build1) ...
# Selecting previously unselected package gettext.
# Preparing to unpack .../16-gettext_0.19.8.1-6ubuntu0.1_amd64.deb ...
# Unpacking gettext (0.19.8.1-6ubuntu0.1) ...
# Selecting previously unselected package intltool-debian.
# Preparing to unpack .../17-intltool-debian_0.35.0+20060710.4_all.deb ...
# Unpacking intltool-debian (0.35.0+20060710.4) ...
# Selecting previously unselected package po-debconf.
# Preparing to unpack .../18-po-debconf_1.0.20_all.deb ...
# Unpacking po-debconf (1.0.20) ...
# Selecting previously unselected package debhelper.
# Preparing to unpack .../19-debhelper_11.1.6ubuntu2_all.deb ...
# Unpacking debhelper (11.1.6ubuntu2) ...
# Selecting previously unselected package gir1.2-atk-1.0:amd64.
# Preparing to unpack .../20-gir1.2-atk-1.0_2.28.1-1_amd64.deb ...
# Unpacking gir1.2-atk-1.0:amd64 (2.28.1-1) ...
# Selecting previously unselected package gir1.2-freedesktop:amd64.
# Preparing to unpack .../21-gir1.2-freedesktop_1.56.1-1_amd64.deb ...
# Unpacking gir1.2-freedesktop:amd64 (1.56.1-1) ...
# Selecting previously unselected package gir1.2-gdkpixbuf-2.0:amd64.
# Preparing to unpack .../22-gir1.2-gdkpixbuf-2.0_2.36.11-2_amd64.deb ...
# Unpacking gir1.2-gdkpixbuf-2.0:amd64 (2.36.11-2) ...
# Selecting previously unselected package libgtk2.0-common.
# Preparing to unpack .../23-libgtk2.0-common_2.24.32-1ubuntu1_all.deb ...
# Unpacking libgtk2.0-common (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libpangoxft-1.0-0:amd64.
# Preparing to unpack .../24-libpangoxft-1.0-0_1.40.14-1ubuntu0.1_amd64.deb ...
# Unpacking libpangoxft-1.0-0:amd64 (1.40.14-1ubuntu0.1) ...
# Selecting previously unselected package gir1.2-pango-1.0:amd64.
# Preparing to unpack .../25-gir1.2-pango-1.0_1.40.14-1ubuntu0.1_amd64.deb ...
# Unpacking gir1.2-pango-1.0:amd64 (1.40.14-1ubuntu0.1) ...
# Selecting previously unselected package libgtk2.0-0:amd64.
# Preparing to unpack .../26-libgtk2.0-0_2.24.32-1ubuntu1_amd64.deb ...
# Unpacking libgtk2.0-0:amd64 (2.24.32-1ubuntu1) ...
# Selecting previously unselected package gir1.2-gtk-2.0.
# Preparing to unpack .../27-gir1.2-gtk-2.0_2.24.32-1ubuntu1_amd64.deb ...
# Unpacking gir1.2-gtk-2.0 (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libarchive-cpio-perl.
# Preparing to unpack .../28-libarchive-cpio-perl_0.10-1_all.deb ...
# Unpacking libarchive-cpio-perl (0.10-1) ...
# Selecting previously unselected package libatk1.0-dev:amd64.
# Preparing to unpack .../29-libatk1.0-dev_2.28.1-1_amd64.deb ...
# Unpacking libatk1.0-dev:amd64 (2.28.1-1) ...
# Selecting previously unselected package libcairo-script-interpreter2:amd64.
# Preparing to unpack .../30-libcairo-script-interpreter2_1.15.10-2ubuntu0.1_amd64.deb ...
# Unpacking libcairo-script-interpreter2:amd64 (1.15.10-2ubuntu0.1) ...
# Selecting previously unselected package libpixman-1-dev:amd64.
# Preparing to unpack .../31-libpixman-1-dev_0.34.0-2_amd64.deb ...
# Unpacking libpixman-1-dev:amd64 (0.34.0-2) ...
# Selecting previously unselected package libxcb-shm0-dev:amd64.
# Preparing to unpack .../32-libxcb-shm0-dev_1.13-1_amd64.deb ...
# Unpacking libxcb-shm0-dev:amd64 (1.13-1) ...
# Selecting previously unselected package libcairo2-dev:amd64.
# Preparing to unpack .../33-libcairo2-dev_1.15.10-2ubuntu0.1_amd64.deb ...
# Unpacking libcairo2-dev:amd64 (1.15.10-2ubuntu0.1) ...
# Selecting previously unselected package libgail18:amd64.
# Preparing to unpack .../34-libgail18_2.24.32-1ubuntu1_amd64.deb ...
# Unpacking libgail18:amd64 (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libgail-common:amd64.
# Preparing to unpack .../35-libgail-common_2.24.32-1ubuntu1_amd64.deb ...
# Unpacking libgail-common:amd64 (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libgdk-pixbuf2.0-dev.
# Preparing to unpack .../36-libgdk-pixbuf2.0-dev_2.36.11-2_amd64.deb ...
# Unpacking libgdk-pixbuf2.0-dev (2.36.11-2) ...
# Selecting previously unselected package libgtk2.0-bin.
# Preparing to unpack .../37-libgtk2.0-bin_2.24.32-1ubuntu1_amd64.deb ...
# Unpacking libgtk2.0-bin (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libpango1.0-dev.
# Preparing to unpack .../38-libpango1.0-dev_1.40.14-1ubuntu0.1_amd64.deb ...
# Unpacking libpango1.0-dev (1.40.14-1ubuntu0.1) ...
# Selecting previously unselected package x11proto-xinerama-dev.
# Preparing to unpack .../39-x11proto-xinerama-dev_2018.4-4_all.deb ...
# Unpacking x11proto-xinerama-dev (2018.4-4) ...
# Selecting previously unselected package libxinerama-dev:amd64.
# Preparing to unpack .../40-libxinerama-dev_2%3a1.1.3-1_amd64.deb ...
# Unpacking libxinerama-dev:amd64 (2:1.1.3-1) ...
# Selecting previously unselected package x11proto-randr-dev.
# Preparing to unpack .../41-x11proto-randr-dev_2018.4-4_all.deb ...
# Unpacking x11proto-randr-dev (2018.4-4) ...
# Selecting previously unselected package libxrandr-dev:amd64.
# Preparing to unpack .../42-libxrandr-dev_2%3a1.5.1-1_amd64.deb ...
# Unpacking libxrandr-dev:amd64 (2:1.5.1-1) ...
# Selecting previously unselected package libxcursor-dev:amd64.
# Preparing to unpack .../43-libxcursor-dev_1%3a1.1.15-1_amd64.deb ...
# Unpacking libxcursor-dev:amd64 (1:1.1.15-1) ...
# Selecting previously unselected package x11proto-composite-dev.
# Preparing to unpack .../44-x11proto-composite-dev_1%3a2018.4-4_all.deb ...
# Unpacking x11proto-composite-dev (1:2018.4-4) ...
# Selecting previously unselected package libxcomposite-dev:amd64.
# Preparing to unpack .../45-libxcomposite-dev_1%3a0.4.4-2_amd64.deb ...
# Unpacking libxcomposite-dev:amd64 (1:0.4.4-2) ...
# Selecting previously unselected package libxml2-utils.
# Preparing to unpack .../46-libxml2-utils_2.9.4+dfsg1-6.1ubuntu1.2_amd64.deb ...
# Unpacking libxml2-utils (2.9.4+dfsg1-6.1ubuntu1.2) ...
# Selecting previously unselected package libgtk2.0-dev.
# Preparing to unpack .../47-libgtk2.0-dev_2.24.32-1ubuntu1_amd64.deb ...
# Unpacking libgtk2.0-dev (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libsys-hostname-long-perl.
# Preparing to unpack .../48-libsys-hostname-long-perl_1.5-1_all.deb ...
# Unpacking libsys-hostname-long-perl (1.5-1) ...
# Selecting previously unselected package libmail-sendmail-perl.
# Preparing to unpack .../49-libmail-sendmail-perl_0.80-1_all.deb ...
# Unpacking libmail-sendmail-perl (0.80-1) ...
# Setting up libxcursor-dev:amd64 (1:1.1.15-1) ...
# Setting up gir1.2-atk-1.0:amd64 (2.28.1-1) ...
# Setting up libgtk2.0-common (2.24.32-1ubuntu1) ...
# Setting up libarchive-zip-perl (1.60-1ubuntu0.1) ...
# Setting up libtimedate-perl (2.3000-2) ...
# Setting up libcairo-script-interpreter2:amd64 (1.15.10-2ubuntu0.1) ...
# Setting up libsigsegv2:amd64 (2.12-1) ...
# Setting up gir1.2-freedesktop:amd64 (1.56.1-1) ...
# Setting up libxcb-shm0-dev:amd64 (1.13-1) ...
# Setting up libpangoxft-1.0-0:amd64 (1.40.14-1ubuntu0.1) ...
# Setting up libxml2-utils (2.9.4+dfsg1-6.1ubuntu1.2) ...
# Setting up libarchive-cpio-perl (0.10-1) ...
# Setting up gir1.2-gdkpixbuf-2.0:amd64 (2.36.11-2) ...
# Setting up libatk1.0-dev:amd64 (2.28.1-1) ...
# Setting up gettext-base (0.19.8.1-6ubuntu0.1) ...
# Setting up m4 (1.4.18-1) ...
# Setting up libmagic-mgc (1:5.32-2ubuntu0.1) ...
# Setting up gir1.2-pango-1.0:amd64 (1.40.14-1ubuntu0.1) ...
# Setting up libmagic1:amd64 (1:5.32-2ubuntu0.1) ...
# Setting up libsys-hostname-long-perl (1.5-1) ...
# Setting up libgdk-pixbuf2.0-dev (2.36.11-2) ...
# Setting up libmail-sendmail-perl (0.80-1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# Setting up x11proto-xinerama-dev (2018.4-4) ...
# Setting up autotools-dev (20180224.1) ...
# Setting up libpixman-1-dev:amd64 (0.34.0-2) ...
# Setting up x11proto-randr-dev (2018.4-4) ...
# Setting up libxinerama-dev:amd64 (2:1.1.3-1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Setting up x11proto-composite-dev (1:2018.4-4) ...
# Setting up autopoint (0.19.8.1-6ubuntu0.1) ...
# Setting up libfile-stripnondeterminism-perl (0.040-1.1~build1) ...
# Setting up libgtk2.0-0:amd64 (2.24.32-1ubuntu1) ...
# Setting up libgail18:amd64 (2.24.32-1ubuntu1) ...
# Setting up libxrandr-dev:amd64 (2:1.5.1-1) ...
# Setting up libcairo2-dev:amd64 (1.15.10-2ubuntu0.1) ...
# Setting up gettext (0.19.8.1-6ubuntu0.1) ...
# Setting up libxcomposite-dev:amd64 (1:0.4.4-2) ...
# Setting up libgail-common:amd64 (2.24.32-1ubuntu1) ...
# Setting up autoconf (2.69-11) ...
# Setting up file (1:5.32-2ubuntu0.1) ...
# Setting up intltool-debian (0.35.0+20060710.4) ...
# Setting up automake (1:1.15.1-3ubuntu2) ...
# update-alternatives: using /usr/bin/automake-1.15 to provide /usr/bin/automake (automake) in auto mode
# Setting up libpango1.0-dev (1.40.14-1ubuntu0.1) ...
# Setting up gir1.2-gtk-2.0 (2.24.32-1ubuntu1) ...
# Setting up libgtk2.0-bin (2.24.32-1ubuntu1) ...
# Setting up libtool (2.4.6-2) ...
# Setting up po-debconf (1.0.20) ...
# Setting up libgtk2.0-dev (2.24.32-1ubuntu1) ...
# Setting up dh-autoreconf (17) ...
# Setting up debhelper (11.1.6ubuntu2) ...
# Setting up dh-strip-nondeterminism (0.040-1.1~build1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...

# %%
# !apt-get install libavcodec-dev libavformat-dev libswscale-d
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# E: Unable to locate package libswscale-d

# %%
# !apt-get -y install cmake
# !which cmake

# !cmake --version
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# cmake is already the newest version (3.10.2-1ubuntu2).
# 0 upgraded, 0 newly installed, 0 to remove and 2 not upgraded.
# /usr/local/bin/cmake
# cmake version 3.12.0
#
# CMake suite maintained and supported by Kitware (kitware.com/cmake).

# %%
# !apt-get install libopencv-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libopencv-dev is already the newest version (3.2.0+dfsg-4ubuntu0.1).
# 0 upgraded, 0 newly installed, 0 to remove and 2 not upgraded.

# %%
# !git clone https://github.com/AlexeyAB/darknet/
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 9324 (delta 2), reused 10 (delta 2), pack-reused 9313
# Receiving objects: 100% (9324/9324), 9.20 MiB | 16.91 MiB/s, done.
# Resolving deltas: 100% (6334/6334), done.

# %%
# !apt-get install vim
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libgpm2 vim-common vim-runtime xxd
# Suggested packages:
#   gpm ctags vim-doc vim-scripts
# The following NEW packages will be installed:
#   libgpm2 vim vim-common vim-runtime xxd
# 0 upgraded, 5 newly installed, 0 to remove and 2 not upgraded.
# Need to get 6,723 kB of archives.
# After this operation, 32.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 xxd amd64 2:8.0.1453-1ubuntu1 [49.2 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 vim-common all 2:8.0.1453-1ubuntu1 [70.4 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgpm2 amd64 1.20.7-5 [15.1 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/main amd64 vim-runtime all 2:8.0.1453-1ubuntu1 [5,437 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/main amd64 vim amd64 2:8.0.1453-1ubuntu1 [1,152 kB]
# Fetched 6,723 kB in 1s (5,501 kB/s)
# Selecting previously unselected package xxd.
# (Reading database ... 133291 files and directories currently installed.)
# Preparing to unpack .../xxd_2%3a8.0.1453-1ubuntu1_amd64.deb ...
# Unpacking xxd (2:8.0.1453-1ubuntu1) ...
# Selecting previously unselected package vim-common.
# Preparing to unpack .../vim-common_2%3a8.0.1453-1ubuntu1_all.deb ...
# Unpacking vim-common (2:8.0.1453-1ubuntu1) ...
# Selecting previously unselected package libgpm2:amd64.
# Preparing to unpack .../libgpm2_1.20.7-5_amd64.deb ...
# Unpacking libgpm2:amd64 (1.20.7-5) ...
# Selecting previously unselected package vim-runtime.
# Preparing to unpack .../vim-runtime_2%3a8.0.1453-1ubuntu1_all.deb ...
# Adding 'diversion of /usr/share/vim/vim80/doc/help.txt to /usr/share/vim/vim80/doc/help.txt.vim-tiny by vim-runtime'
# Adding 'diversion of /usr/share/vim/vim80/doc/tags to /usr/share/vim/vim80/doc/tags.vim-tiny by vim-runtime'
# Unpacking vim-runtime (2:8.0.1453-1ubuntu1) ...
# Selecting previously unselected package vim.
# Preparing to unpack .../vim_2%3a8.0.1453-1ubuntu1_amd64.deb ...
# Unpacking vim (2:8.0.1453-1ubuntu1) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Setting up xxd (2:8.0.1453-1ubuntu1) ...
# Setting up libgpm2:amd64 (1.20.7-5) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# Setting up vim-common (2:8.0.1453-1ubuntu1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Setting up vim-runtime (2:8.0.1453-1ubuntu1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Setting up vim (2:8.0.1453-1ubuntu1) ...
# update-alternatives: using /usr/bin/vim.basic to provide /usr/bin/vim (vim) in auto mode
# update-alternatives: using /usr/bin/vim.basic to provide /usr/bin/vimdiff (vimdiff) in auto mode
# update-alternatives: using /usr/bin/vim.basic to provide /usr/bin/rvim (rvim) in auto mode
# update-alternatives: using /usr/bin/vim.basic to provide /usr/bin/rview (rview) in auto mode
# update-alternatives: using /usr/bin/vim.basic to provide /usr/bin/vi (vi) in auto mode
# update-alternatives: using /usr/bin/vim.basic to provide /usr/bin/view (view) in auto mode
# update-alternatives: using /usr/bin/vim.basic to provide /usr/bin/ex (ex) in auto mode
# update-alternatives: using /usr/bin/vim.basic to provide /usr/bin/editor (editor) in auto mode

# %%
# %cd darknet
# Out:
# /content/darknet

# %%
# !ls
# !wget https://pjreddie.com/media/files/yolov3.weights
# Out:
# 3rdparty      cmake		  image_yolov2.sh	 net_cam_v3.sh
# appveyor.yml  CMakeLists.txt	  image_yolov3.sh	 README.md
# build	      CMakeSettings.json  include		 scripts
# build.ps1     darknet.py	  json_mjpeg_streams.sh  src
# build.sh      darknet_video.py	  LICENSE		 video_v2.sh
# cfg	      data		  Makefile		 video_yolov3.sh
# --2019-03-04 10:28:48--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.3.39
# Connecting to pjreddie.com (pjreddie.com)|128.208.3.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  63.5MB/s    in 3.9s
#
# 2019-03-04 10:28:52 (60.1 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %%
# !ls
# !sed -i 's/OPENCV=0/OPENCV=1/g' Makefile
# !sed -i 's/GPU=0/GPU=1/g' Makefile
# Out:
# 3rdparty      CMakeLists.txt	  include		 src
# appveyor.yml  CMakeSettings.json  json_mjpeg_streams.sh  video_v2.sh
# build	      darknet.py	  LICENSE		 video_yolov3.sh
# build.ps1     darknet_video.py	  Makefile		 yolov3.weights
# build.sh      data		  net_cam_v3.sh
# cfg	      image_yolov2.sh	  README.md
# cmake	      image_yolov3.sh	  scripts

# %%
# !ls
# %cd ../
# !ls
# Out:
# 3rdparty      CMakeLists.txt	  include		 src
# appveyor.yml  CMakeSettings.json  json_mjpeg_streams.sh  video_v2.sh
# build	      darknet.py	  LICENSE		 video_yolov3.sh
# build.ps1     darknet_video.py	  Makefile		 yolov3.weights
# build.sh      data		  net_cam_v3.sh
# cfg	      image_yolov2.sh	  README.md
# cmake	      image_yolov3.sh	  scripts
# /content
# darknet  sample_data

# %%
# !apt install g++-5
# !apt install gcc-5

# !update-alternatives --install /usr/bin/gcc gcc /usr/bin/gcc-5 10
# !update-alternatives --install /usr/bin/gcc gcc /usr/bin/gcc-5 20
# !update-alternatives --install /usr/bin/g++ g++ /usr/bin/g++-5 10
# !update-alternatives --install /usr/bin/g++ g++ /usr/bin/g++-5 20
# !update-alternatives --install /usr/bin/cc cc /usr/bin/gcc 30
# !update-alternatives --set cc /usr/bin/gcc
# !update-alternatives --install /usr/bin/c++ c++ /usr/bin/g++ 30
# !update-alternatives --set c++ /usr/bin/g++
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   cpp-5 gcc-5 gcc-5-base libasan2 libgcc-5-dev libisl15 libmpx0
#   libstdc++-5-dev
# Suggested packages:
#   gcc-5-locales g++-5-multilib gcc-5-doc libstdc++6-5-dbg gcc-5-multilib
#   libgcc1-dbg libgomp1-dbg libitm1-dbg libatomic1-dbg libasan2-dbg
#   liblsan0-dbg libtsan0-dbg libubsan0-dbg libcilkrts5-dbg libmpx0-dbg
#   libquadmath0-dbg libstdc++-5-doc
# The following NEW packages will be installed:
#   cpp-5 g++-5 gcc-5 gcc-5-base libasan2 libgcc-5-dev libisl15 libmpx0
#   libstdc++-5-dev
# 0 upgraded, 9 newly installed, 0 to remove and 2 not upgraded.
# Need to get 29.1 MB of archives.
# After this operation, 100 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 gcc-5-base amd64 5.5.0-12ubuntu1 [17.1 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libisl15 amd64 0.18-4 [548 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/universe amd64 cpp-5 amd64 5.5.0-12ubuntu1 [7,785 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libasan2 amd64 5.5.0-12ubuntu1 [264 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libmpx0 amd64 5.5.0-12ubuntu1 [9,888 B]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgcc-5-dev amd64 5.5.0-12ubuntu1 [2,224 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/universe amd64 gcc-5 amd64 5.5.0-12ubuntu1 [8,357 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libstdc++-5-dev amd64 5.5.0-12ubuntu1 [1,415 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/universe amd64 g++-5 amd64 5.5.0-12ubuntu1 [8,450 kB]
# Fetched 29.1 MB in 2s (14.8 MB/s)
# Selecting previously unselected package gcc-5-base:amd64.
# (Reading database ... 135134 files and directories currently installed.)
# Preparing to unpack .../0-gcc-5-base_5.5.0-12ubuntu1_amd64.deb ...
# Unpacking gcc-5-base:amd64 (5.5.0-12ubuntu1) ...
# Selecting previously unselected package libisl15:amd64.
# Preparing to unpack .../1-libisl15_0.18-4_amd64.deb ...
# Unpacking libisl15:amd64 (0.18-4) ...
# Selecting previously unselected package cpp-5.
# Preparing to unpack .../2-cpp-5_5.5.0-12ubuntu1_amd64.deb ...
# Unpacking cpp-5 (5.5.0-12ubuntu1) ...
# Selecting previously unselected package libasan2:amd64.
# Preparing to unpack .../3-libasan2_5.5.0-12ubuntu1_amd64.deb ...
# Unpacking libasan2:amd64 (5.5.0-12ubuntu1) ...
# Selecting previously unselected package libmpx0:amd64.
# Preparing to unpack .../4-libmpx0_5.5.0-12ubuntu1_amd64.deb ...
# Unpacking libmpx0:amd64 (5.5.0-12ubuntu1) ...
# Selecting previously unselected package libgcc-5-dev:amd64.
# Preparing to unpack .../5-libgcc-5-dev_5.5.0-12ubuntu1_amd64.deb ...
# Unpacking libgcc-5-dev:amd64 (5.5.0-12ubuntu1) ...
# Selecting previously unselected package gcc-5.
# Preparing to unpack .../6-gcc-5_5.5.0-12ubuntu1_amd64.deb ...
# Unpacking gcc-5 (5.5.0-12ubuntu1) ...
# Selecting previously unselected package libstdc++-5-dev:amd64.
# Preparing to unpack .../7-libstdc++-5-dev_5.5.0-12ubuntu1_amd64.deb ...
# Unpacking libstdc++-5-dev:amd64 (5.5.0-12ubuntu1) ...
# Selecting previously unselected package g++-5.
# Preparing to unpack .../8-g++-5_5.5.0-12ubuntu1_amd64.deb ...
# Unpacking g++-5 (5.5.0-12ubuntu1) ...
# Setting up libisl15:amd64 (0.18-4) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Setting up gcc-5-base:amd64 (5.5.0-12ubuntu1) ...
# Setting up libmpx0:amd64 (5.5.0-12ubuntu1) ...
# Setting up libasan2:amd64 (5.5.0-12ubuntu1) ...
# Setting up libgcc-5-dev:amd64 (5.5.0-12ubuntu1) ...
# Setting up cpp-5 (5.5.0-12ubuntu1) ...
# Setting up libstdc++-5-dev:amd64 (5.5.0-12ubuntu1) ...
# Setting up gcc-5 (5.5.0-12ubuntu1) ...
# Setting up g++-5 (5.5.0-12ubuntu1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# gcc-5 is already the newest version (5.5.0-12ubuntu1).
# gcc-5 set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 2 not upgraded.
# update-alternatives: using /usr/bin/gcc-5 to provide /usr/bin/gcc (gcc) in auto mode
# update-alternatives: using /usr/bin/g++-5 to provide /usr/bin/g++ (g++) in auto mode

# %%
# !apt update -qq;
# !wget https://developer.nvidia.com/compute/cuda/8.0/Prod2/local_installers/cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64-deb
# !dpkg -i cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64-deb
# !apt-get update -qq

#Here were are installing compilers and creating some links
# !apt-get install cuda -y -qq #gcc-5 g++-5 
#!ln -s /usr/bin/gcc-5 /usr/local/cuda/bin/gcc
#!ln -s /usr/bin/g++-5 /usr/local/cuda/bin/g++
# !apt update
# !apt upgrade
# !apt install cuda-8.0 -y
# Out:
# 34 packages can be upgraded. Run 'apt list --upgradable' to see them.
# --2019-03-04 10:34:27--  https://developer.nvidia.com/compute/cuda/8.0/Prod2/local_installers/cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64-deb
# Resolving developer.nvidia.com (developer.nvidia.com)... 192.229.162.216
# Connecting to developer.nvidia.com (developer.nvidia.com)|192.229.162.216|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://developer.download.nvidia.com/compute/cuda/8.0/secure/Prod2/local_installers/cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64.deb?5sBdmpBQ3gAML07tSabqY4pBdey5-RzW8mAtF76A4G3ilDKctFQRIyLVmDSN8XMdceW5njY0Mphck9STHo-FnstdQxV7-U2aMx-6H_wm8eZGj84Ekffg0VtuMKh6Q9vaOHTt7R3bxRWz9PfC2ETIf92zeR4tT1qweWsOCsifqXrahVo6pM7zxm4QnqUZN8_UTE7SC4Pf8kWBkIIlZp45iAY3zQ [following]
# --2019-03-04 10:34:28--  https://developer.download.nvidia.com/compute/cuda/8.0/secure/Prod2/local_installers/cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64.deb?5sBdmpBQ3gAML07tSabqY4pBdey5-RzW8mAtF76A4G3ilDKctFQRIyLVmDSN8XMdceW5njY0Mphck9STHo-FnstdQxV7-U2aMx-6H_wm8eZGj84Ekffg0VtuMKh6Q9vaOHTt7R3bxRWz9PfC2ETIf92zeR4tT1qweWsOCsifqXrahVo6pM7zxm4QnqUZN8_UTE7SC4Pf8kWBkIIlZp45iAY3zQ
# Resolving developer.download.nvidia.com (developer.download.nvidia.com)... 192.229.211.70, 2606:2800:21f:3aa:dcf:37b:1ed6:1fb
# Connecting to developer.download.nvidia.com (developer.download.nvidia.com)|192.229.211.70|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1913589814 (1.8G) [application/x-deb]
# Saving to: ‘cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64-deb’
#
# cuda-repo-ubuntu160 100%[===================>]   1.78G   132MB/s    in 13s
#
# 2019-03-04 10:34:41 (141 MB/s) - ‘cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64-deb’ saved [1913589814/1913589814]
#
# Selecting previously unselected package cuda-repo-ubuntu1604-8-0-local-ga2.
# (Reading database ... 136134 files and directories currently installed.)
# Preparing to unpack cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64-deb ...
# Unpacking cuda-repo-ubuntu1604-8-0-local-ga2 (8.0.61-1) ...
# Setting up cuda-repo-ubuntu1604-8-0-local-ga2 (8.0.61-1) ...
# Warning: The postinst maintainerscript of the package cuda-repo-ubuntu1604-8-0-local-ga2
# Warning: seems to use apt-key (provided by apt) without depending on gnupg or gnupg2.
# Warning: This will BREAK in the future and should be fixed by the package maintainer(s).
# Note: Check first if apt-key functionality is needed at all - it probably isn't!
# Warning: apt-key should not be used in scripts (called from postinst maintainerscript of the package cuda-repo-ubuntu1604-8-0-local-ga2)
# OK
# Extracting templates from packages: 100%
# Selecting previously unselected package libnvidia-common-418.
# (Reading database ... 136228 files and directories currently installed.)
# Preparing to unpack .../libnvidia-common-418_418.39-0ubuntu1_all.deb ...
# Unpacking libnvidia-common-418 (418.39-0ubuntu1) ...
# Preparing to unpack .../cuda-drivers_418.39-1_amd64.deb ...
# Unpacking cuda-drivers (418.39-1) over (410.79-1) ...
# (Reading database ... 136233 files and directories currently installed.)
# Removing nvidia-driver-410 (410.79-0ubuntu1) ...
# Removing libnvidia-encode-410:amd64 (410.79-0ubuntu1) ...
# Removing libnvidia-decode-410:amd64 (410.79-0ubuntu1) ...
# Removing nvidia-utils-410 (410.79-0ubuntu1) ...
# dpkg: libnvidia-compute-410:amd64: dependency problems, but removing anyway as you requested:
#  nvidia-compute-utils-410 depends on libnvidia-compute-410.
#  libnvidia-gl-410:amd64 depends on libnvidia-compute-410.
#
# Removing libnvidia-compute-410:amd64 (410.79-0ubuntu1) ...
# Selecting previously unselected package libnvidia-compute-418:amd64.
# (Reading database ... 136134 files and directories currently installed.)
# Preparing to unpack .../libnvidia-compute-418_418.39-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-compute-418:amd64 (418.39-0ubuntu1) ...
# Selecting previously unselected package libnvidia-decode-418:amd64.
# Preparing to unpack .../libnvidia-decode-418_418.39-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-decode-418:amd64 (418.39-0ubuntu1) ...
# Selecting previously unselected package libnvidia-encode-418:amd64.
# Preparing to unpack .../libnvidia-encode-418_418.39-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-encode-418:amd64 (418.39-0ubuntu1) ...
# (Reading database ... 136168 files and directories currently installed.)
# Removing libnvidia-fbc1-410:amd64 (410.79-0ubuntu1) ...
# Selecting previously unselected package libnvidia-fbc1-418:amd64.
# (Reading database ... 136162 files and directories currently installed.)
# Preparing to unpack .../libnvidia-fbc1-418_418.39-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-fbc1-418:amd64 (418.39-0ubuntu1) ...
# (Reading database ... 136168 files and directories currently installed.)
# Removing libnvidia-ifr1-410:amd64 (410.79-0ubuntu1) ...
# Removing libnvidia-gl-410:amd64 (410.79-0ubuntu1) ...
# Selecting previously unselected package libnvidia-gl-418:amd64.
# (Reading database ... 136130 files and directories currently installed.)
# Preparing to unpack .../libnvidia-gl-418_418.39-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-gl-418:amd64 (418.39-0ubuntu1) ...
# Selecting previously unselected package libnvidia-ifr1-418:amd64.
# Preparing to unpack .../libnvidia-ifr1-418_418.39-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-ifr1-418:amd64 (418.39-0ubuntu1) ...
# (Reading database ... 136169 files and directories currently installed.)
# Removing nvidia-compute-utils-410 (410.79-0ubuntu1) ...
# System has not been booted with systemd as init system (PID 1). Can't operate.
# Selecting previously unselected package nvidia-compute-utils-418.
# (Reading database ... 136158 files and directories currently installed.)
# Preparing to unpack .../nvidia-compute-utils-418_418.39-0ubuntu1_amd64.deb ...
# Unpacking nvidia-compute-utils-418 (418.39-0ubuntu1) ...
# (Reading database ... 136169 files and directories currently installed.)
# Removing nvidia-dkms-410 (410.79-0ubuntu1) ...
# Removing all DKMS Modules
# Done.
# Removing nvidia-kernel-source-410 (410.79-0ubuntu1) ...
# Selecting previously unselected package nvidia-kernel-source-418.
# (Reading database ... 135791 files and directories currently installed.)
# Preparing to unpack .../nvidia-kernel-source-418_418.39-0ubuntu1_amd64.deb ...
# Unpacking nvidia-kernel-source-418 (418.39-0ubuntu1) ...
# (Reading database ... 136144 files and directories currently installed.)
# Removing nvidia-kernel-common-410 (410.79-0ubuntu1) ...
# Selecting previously unselected package nvidia-kernel-common-418.
# (Reading database ... 136137 files and directories currently installed.)
# Preparing to unpack .../nvidia-kernel-common-418_418.39-0ubuntu1_amd64.deb ...
# Unpacking nvidia-kernel-common-418 (418.39-0ubuntu1) ...
# Selecting previously unselected package nvidia-dkms-418.
# Preparing to unpack .../nvidia-dkms-418_418.39-0ubuntu1_amd64.deb ...
# Unpacking nvidia-dkms-418 (418.39-0ubuntu1) ...
# Selecting previously unselected package nvidia-utils-418.
# Preparing to unpack .../nvidia-utils-418_418.39-0ubuntu1_amd64.deb ...
# Unpacking nvidia-utils-418 (418.39-0ubuntu1) ...
# (Reading database ... 136182 files and directories currently installed.)
# Removing xserver-xorg-video-nvidia-410 (410.79-0ubuntu1) ...
# Removing libnvidia-cfg1-410:amd64 (410.79-0ubuntu1) ...
# Selecting previously unselected package libnvidia-cfg1-418:amd64.
# (Reading database ... 136169 files and directories currently installed.)
# Preparing to unpack .../00-libnvidia-cfg1-418_418.39-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-cfg1-418:amd64 (418.39-0ubuntu1) ...
# Selecting previously unselected package xserver-xorg-input-libinput.
# Preparing to unpack .../01-xserver-xorg-input-libinput_0.27.1-1_amd64.deb ...
# Unpacking xserver-xorg-input-libinput (0.27.1-1) ...
# Selecting previously unselected package xserver-xorg-input-all.
# Preparing to unpack .../02-xserver-xorg-input-all_1%3a7.7+19ubuntu7.1_amd64.deb ...
# Unpacking xserver-xorg-input-all (1:7.7+19ubuntu7.1) ...
# Selecting previously unselected package xserver-xorg-video-nvidia-418.
# Preparing to unpack .../03-xserver-xorg-video-nvidia-418_418.39-0ubuntu1_amd64.deb ...
# Unpacking xserver-xorg-video-nvidia-418 (418.39-0ubuntu1) ...
# Selecting previously unselected package nvidia-driver-418.
# Preparing to unpack .../04-nvidia-driver-418_418.39-0ubuntu1_amd64.deb ...
# Unpacking nvidia-driver-418 (418.39-0ubuntu1) ...
# Preparing to unpack .../05-nvidia-modprobe_418.39-0ubuntu1_amd64.deb ...
# Unpacking nvidia-modprobe (418.39-0ubuntu1) over (410.79-0ubuntu1) ...
# Preparing to unpack .../06-nvidia-settings_418.39-0ubuntu1_amd64.deb ...
# Unpacking nvidia-settings (418.39-0ubuntu1) over (415.27-0ubuntu0~gpu18.04.1) ...
# Selecting previously unselected package cuda-license-10-1.
# Preparing to unpack .../07-cuda-license-10-1_10.1.105-1_amd64.deb ...
# Unpacking cuda-license-10-1 (10.1.105-1) ...
# Selecting previously unselected package cuda-misc-headers-10-1.
# Preparing to unpack .../08-cuda-misc-headers-10-1_10.1.105-1_amd64.deb ...
# Unpacking cuda-misc-headers-10-1 (10.1.105-1) ...
# Selecting previously unselected package cuda-nvcc-10-1.
# Preparing to unpack .../09-cuda-nvcc-10-1_10.1.105-1_amd64.deb ...
# Unpacking cuda-nvcc-10-1 (10.1.105-1) ...
# Selecting previously unselected package cuda-cuobjdump-10-1.
# Preparing to unpack .../10-cuda-cuobjdump-10-1_10.1.105-1_amd64.deb ...
# Unpacking cuda-cuobjdump-10-1 (10.1.105-1) ...
# Selecting previously unselected package cuda-nvprune-10-1.
# Preparing to unpack .../11-cuda-nvprune-10-1_10.1.105-1_amd64.deb ...
# Unpacking cuda-nvprune-10-1 (10.1.105-1) ...
# Selecting previously unselected package cuda-compiler-10-1.
# Preparing to unpack .../12-cuda-compiler-10-1_10.1.105-1_amd64.deb ...
# Unpacking cuda-compiler-10-1 (10.1.105-1) ...
# Selecting previously unselected package cuda-nvdisasm-10-1.
# Preparing to unpack .../13-cuda-nvdisasm-10-1_10.1.105-1_amd64.deb ...
# Unpacking cuda-nvdisasm-10-1 (10.1.105-1) ...
# Selecting previously unselected package cuda-gdb-10-1.
# Preparing to unpack .../14-cuda-gdb-10-1_10.1.105-1_amd64.deb ...
# Unpacking cuda-gdb-10-1 (10.1.105-1) ...
# Selecting previously unselected package cuda-nvprof-10-1.
# Preparing to unpack .../15-cuda-nvprof-10-1_10.1.105-1_amd64.deb ...
# Unpacking cuda-nvprof-10-1 (10.1.105-1) ...
# Selecting previously unselected package cuda-sanitizer-api-10-1.
# Preparing to unpack .../16-cuda-sanitizer-api-10-1_10.1.105-1_amd64.deb ...
# Unpacking cuda-sanitizer-api-10-1 (10.1.105-1) ...
# Selecting previously unselected package cuda-memcheck-10-1.
# Preparing to unpack .../17-cuda-memcheck-10-1_10.1.105-1_amd64.deb ...
# Unpacking cuda-memcheck-10-1 (10.1.105-1) ...
# Selecting previously unselected package cuda-cudart-10-1.
# Preparing to unpack .../18-cuda-cudart-10-1_10.1.105-1_amd64.deb ...
# Unpacking cuda-cudart-10-1 (10.1.105-1) ...
# Selecting previously unselected package cuda-driver-dev-10-1.
# Preparing to unpack .../19-cuda-driver-dev-10-1_10.1.105-1_amd64.deb ...
# Unpacking cuda-driver-dev-10-1 (10.1.105-1) ...
# Selecting previously unselected package cuda-cudart-dev-10-1.
# Preparing to unpack .../20-cuda-cudart-dev-10-1_10.1.105-1_amd64.deb ...
# Unpacking cuda-cudart-dev-10-1 (10.1.105-1) ...
# Selecting previously unselected package cuda-cupti-10-1.
# Preparing to unpack .../21-cuda-cupti-10-1_10.1.105-1_amd64.deb ...
# Unpacking cuda-cupti-10-1 (10.1.105-1) ...
# Selecting previously unselected package cuda-gpu-library-advisor-10-1.
# Preparing to unpack .../22-cuda-gpu-library-advisor-10-1_10.1.105-1_amd64.deb ...
# Unpacking cuda-gpu-library-advisor-10-1 (10.1.105-1) ...
# Selecting previously unselected package cuda-nvtx-10-1.
# Preparing to unpack .../23-cuda-nvtx-10-1_10.1.105-1_amd64.deb ...
# Unpacking cuda-nvtx-10-1 (10.1.105-1) ...
# Selecting previously unselected package cuda-command-line-tools-10-1.
# Preparing to unpack .../24-cuda-command-line-tools-10-1_10.1.105-1_amd64.deb ...
# Unpacking cuda-command-line-tools-10-1 (10.1.105-1) ...
# Selecting previously unselected package cuda-nsight-10-1.
# Preparing to unpack .../25-cuda-nsight-10-1_10.1.105-1_amd64.deb ...
# Unpacking cuda-nsight-10-1 (10.1.105-1) ...
# Selecting previously unselected package cuda-nvvp-10-1.
# Preparing to unpack .../26-cuda-nvvp-10-1_10.1.105-1_amd64.deb ...
# Unpacking cuda-nvvp-10-1 (10.1.105-1) ...
# Selecting previously unselected package cuda-nvrtc-10-1.
# Preparing to unpack .../27-cuda-nvrtc-10-1_10.1.105-1_amd64.deb ...
# Unpacking cuda-nvrtc-10-1 (10.1.105-1) ...
# Selecting previously unselected package cuda-nvrtc-dev-10-1.
# Preparing to unpack .../28-cuda-nvrtc-dev-10-1_10.1.105-1_amd64.deb ...
# Unpacking cuda-nvrtc-dev-10-1 (10.1.105-1) ...
# Selecting previously unselected package cuda-cusolver-10-1.
# Preparing to unpack .../29-cuda-cusolver-10-1_10.1.105-1_amd64.deb ...
# Unpacking cuda-cusolver-10-1 (10.1.105-1) ...
# Selecting previously unselected package cuda-cusolver-dev-10-1.
# Preparing to unpack .../30-cuda-cusolver-dev-10-1_10.1.105-1_amd64.deb ...
# Unpacking cuda-cusolver-dev-10-1 (10.1.105-1) ...
# Selecting previously unselected package libcublas10.
# Preparing to unpack .../31-libcublas10_10.1.0.105-1_amd64.deb ...
# Unpacking libcublas10 (10.1.0.105-1) ...
# Selecting previously unselected package libcublas-dev.
# Preparing to unpack .../32-libcublas-dev_10.1.0.105-1_amd64.deb ...
# Unpacking libcublas-dev (10.1.0.105-1) ...
# Selecting previously unselected package cuda-cufft-10-1.
# Preparing to unpack .../33-cuda-cufft-10-1_10.1.105-1_amd64.deb ...
# Unpacking cuda-cufft-10-1 (10.1.105-1) ...
# Selecting previously unselected package cuda-cufft-dev-10-1.
# Preparing to unpack .../34-cuda-cufft-dev-10-1_10.1.105-1_amd64.deb ...
# Unpacking cuda-cufft-dev-10-1 (10.1.105-1) ...
# Selecting previously unselected package cuda-curand-10-1.
# Preparing to unpack .../35-cuda-curand-10-1_10.1.105-1_amd64.deb ...
# Unpacking cuda-curand-10-1 (10.1.105-1) ...
# Selecting previously unselected package cuda-curand-dev-10-1.
# Preparing to unpack .../36-cuda-curand-dev-10-1_10.1.105-1_amd64.deb ...
# Unpacking cuda-curand-dev-10-1 (10.1.105-1) ...
# Selecting previously unselected package cuda-cusparse-10-1.
# Preparing to unpack .../37-cuda-cusparse-10-1_10.1.105-1_amd64.deb ...
# Unpacking cuda-cusparse-10-1 (10.1.105-1) ...
# Selecting previously unselected package cuda-cusparse-dev-10-1.
# Preparing to unpack .../38-cuda-cusparse-dev-10-1_10.1.105-1_amd64.deb ...
# Unpacking cuda-cusparse-dev-10-1 (10.1.105-1) ...
# Selecting previously unselected package cuda-npp-10-1.
# Preparing to unpack .../39-cuda-npp-10-1_10.1.105-1_amd64.deb ...
# Unpacking cuda-npp-10-1 (10.1.105-1) ...
# Selecting previously unselected package cuda-npp-dev-10-1.
# Preparing to unpack .../40-cuda-npp-dev-10-1_10.1.105-1_amd64.deb ...
# Unpacking cuda-npp-dev-10-1 (10.1.105-1) ...
# Selecting previously unselected package cuda-nvml-dev-10-1.
# Preparing to unpack .../41-cuda-nvml-dev-10-1_10.1.105-1_amd64.deb ...
# Unpacking cuda-nvml-dev-10-1 (10.1.105-1) ...
# Selecting previously unselected package cuda-nvjpeg-10-1.
# Preparing to unpack .../42-cuda-nvjpeg-10-1_10.1.105-1_amd64.deb ...
# Unpacking cuda-nvjpeg-10-1 (10.1.105-1) ...
# Selecting previously unselected package cuda-nvjpeg-dev-10-1.
# Preparing to unpack .../43-cuda-nvjpeg-dev-10-1_10.1.105-1_amd64.deb ...
# Unpacking cuda-nvjpeg-dev-10-1 (10.1.105-1) ...
# Selecting previously unselected package cuda-nsight-compute-10-1.
# Preparing to unpack .../44-cuda-nsight-compute-10-1_10.1.105-1_amd64.deb ...
# Unpacking cuda-nsight-compute-10-1 (10.1.105-1) ...
# Selecting previously unselected package cuda-nsight-systems-10-1.
# Preparing to unpack .../45-cuda-nsight-systems-10-1_10.1.105-1_amd64.deb ...
# Unpacking cuda-nsight-systems-10-1 (10.1.105-1) ...
# Selecting previously unselected package cuda-nvgraph-10-1.
# Preparing to unpack .../46-cuda-nvgraph-10-1_10.1.105-1_amd64.deb ...
# Unpacking cuda-nvgraph-10-1 (10.1.105-1) ...
# Selecting previously unselected package cuda-nvgraph-dev-10-1.
# Preparing to unpack .../47-cuda-nvgraph-dev-10-1_10.1.105-1_amd64.deb ...
# Unpacking cuda-nvgraph-dev-10-1 (10.1.105-1) ...
# Selecting previously unselected package cuda-visual-tools-10-1.
# Preparing to unpack .../48-cuda-visual-tools-10-1_10.1.105-1_amd64.deb ...
# Unpacking cuda-visual-tools-10-1 (10.1.105-1) ...
# Selecting previously unselected package cuda-tools-10-1.
# Preparing to unpack .../49-cuda-tools-10-1_10.1.105-1_amd64.deb ...
# Unpacking cuda-tools-10-1 (10.1.105-1) ...
# Selecting previously unselected package cuda-samples-10-1.
# Preparing to unpack .../50-cuda-samples-10-1_10.1.105-1_amd64.deb ...
# Unpacking cuda-samples-10-1 (10.1.105-1) ...
# Selecting previously unselected package cuda-documentation-10-1.
# Preparing to unpack .../51-cuda-documentation-10-1_10.1.105-1_amd64.deb ...
# Unpacking cuda-documentation-10-1 (10.1.105-1) ...
# Selecting previously unselected package cuda-libraries-dev-10-1.
# Preparing to unpack .../52-cuda-libraries-dev-10-1_10.1.105-1_amd64.deb ...
# Unpacking cuda-libraries-dev-10-1 (10.1.105-1) ...
# Selecting previously unselected package cuda-toolkit-10-1.
# Preparing to unpack .../53-cuda-toolkit-10-1_10.1.105-1_amd64.deb ...
# Unpacking cuda-toolkit-10-1 (10.1.105-1) ...
# Selecting previously unselected package cuda-libraries-10-1.
# Preparing to unpack .../54-cuda-libraries-10-1_10.1.105-1_amd64.deb ...
# Unpacking cuda-libraries-10-1 (10.1.105-1) ...
# Selecting previously unselected package cuda-runtime-10-1.
# Preparing to unpack .../55-cuda-runtime-10-1_10.1.105-1_amd64.deb ...
# Unpacking cuda-runtime-10-1 (10.1.105-1) ...
# Selecting previously unselected package cuda-demo-suite-10-1.
# Preparing to unpack .../56-cuda-demo-suite-10-1_10.1.105-1_amd64.deb ...
# Unpacking cuda-demo-suite-10-1 (10.1.105-1) ...
# Selecting previously unselected package cuda-10-1.
# Preparing to unpack .../57-cuda-10-1_10.1.105-1_amd64.deb ...
# Unpacking cuda-10-1 (10.1.105-1) ...
# Preparing to unpack .../58-cuda_10.1.105-1_amd64.deb ...
# Unpacking cuda (10.1.105-1) over (10.0.130-1) ...
# Selecting previously unselected package nvidia-prime.
# Preparing to unpack .../59-nvidia-prime_0.8.8.2_all.deb ...
# Unpacking nvidia-prime (0.8.8.2) ...
# Selecting previously unselected package xserver-xorg-input-wacom.
# Preparing to unpack .../60-xserver-xorg-input-wacom_1%3a0.36.1-0ubuntu1_amd64.deb ...
# Unpacking xserver-xorg-input-wacom (1:0.36.1-0ubuntu1) ...
# Setting up libnvidia-fbc1-418:amd64 (418.39-0ubuntu1) ...
# Setting up libnvidia-common-418 (418.39-0ubuntu1) ...
# Setting up nvidia-kernel-source-418 (418.39-0ubuntu1) ...
# Setting up nvidia-prime (0.8.8.2) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Setting up libnvidia-compute-418:amd64 (418.39-0ubuntu1) ...
# Setting up xserver-xorg-input-libinput (0.27.1-1) ...
# Setting up nvidia-utils-418 (418.39-0ubuntu1) ...
# Setting up nvidia-kernel-common-418 (418.39-0ubuntu1) ...
# Setting up cuda-license-10-1 (10.1.105-1) ...
# *** LICENSE AGREEMENT ***
# By using this software you agree to fully comply with the terms and
# conditions of the EULA (End User License Agreement). The EULA is located
# at /usr/local/cuda-10.1/doc/EULA.txt. The EULA can also be found at
# http://docs.nvidia.com/cuda/eula/index.html. If you do not agree to the
# terms and conditions of the EULA, do not use the software.
#
# Setting up cuda-cusparse-10-1 (10.1.105-1) ...
# Setting up cuda-nvjpeg-10-1 (10.1.105-1) ...
# Setting up cuda-nsight-10-1 (10.1.105-1) ...
# Setting up cuda-nvdisasm-10-1 (10.1.105-1) ...
# Setting up cuda-nvml-dev-10-1 (10.1.105-1) ...
# Setting up nvidia-settings (418.39-0ubuntu1) ...
# Setting up cuda-sanitizer-api-10-1 (10.1.105-1) ...
# Setting up cuda-nvjpeg-dev-10-1 (10.1.105-1) ...
# Setting up cuda-cufft-10-1 (10.1.105-1) ...
# Setting up cuda-nvprof-10-1 (10.1.105-1) ...
# Setting up cuda-nvrtc-10-1 (10.1.105-1) ...
# Setting up libcublas10 (10.1.0.105-1) ...
# Setting up libcublas-dev (10.1.0.105-1) ...
# Setting up libnvidia-gl-418:amd64 (418.39-0ubuntu1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# Setting up cuda-npp-10-1 (10.1.105-1) ...
# Setting up nvidia-compute-utils-418 (418.39-0ubuntu1) ...
# Warning: The home dir /nonexistent you specified can't be accessed: No such file or directory
# Adding system user `nvidia-persistenced' (UID 103) ...
# Adding new group `nvidia-persistenced' (GID 105) ...
# Adding new user `nvidia-persistenced' (UID 103) with group `nvidia-persistenced' ...
# Not creating home directory `/nonexistent'.
# Created symlink /etc/systemd/system/multi-user.target.wants/nvidia-persistenced.service → /lib/systemd/system/nvidia-persistenced.service.
# Setting up cuda-cufft-dev-10-1 (10.1.105-1) ...
# Setting up libnvidia-cfg1-418:amd64 (418.39-0ubuntu1) ...
# Setting up nvidia-modprobe (418.39-0ubuntu1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Setting up cuda-nvvp-10-1 (10.1.105-1) ...
# Setting up xserver-xorg-input-wacom (1:0.36.1-0ubuntu1) ...
# Setting up nvidia-dkms-418 (418.39-0ubuntu1) ...
#
# A modprobe blacklist file has been created at /etc/modprobe.d to prevent Nouveau
# from loading. This can be reverted by deleting the following file:
# /etc/modprobe.d/nvidia-graphics-drivers.conf
#
# A new initrd image has also been created. To revert, please regenerate your
# initrd by running the following command after deleting the modprobe.d file:
# `/usr/sbin/initramfs -u`
#
# *****************************************************************************
# *** Reboot your computer and verify that the NVIDIA graphics driver can   ***
# *** be loaded.                                                            ***
# *****************************************************************************
#
# Loading new nvidia-418.39 DKMS files...
# It is likely that 4.14.79+ belongs to a chroot's host
# Building for 4.15.0-45-generic
# Building for architecture x86_64
# Building initial module for 4.15.0-45-generic
# Done.
#
# nvidia:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.15.0-45-generic/updates/dkms/
#
# nvidia-modeset.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.15.0-45-generic/updates/dkms/
#
# nvidia-drm.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.15.0-45-generic/updates/dkms/
#
# nvidia-uvm.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.15.0-45-generic/updates/dkms/
#
# depmod...
#
# DKMS: install completed.
# Setting up cuda-driver-dev-10-1 (10.1.105-1) ...
# Setting up cuda-cuobjdump-10-1 (10.1.105-1) ...
# Setting up libnvidia-ifr1-418:amd64 (418.39-0ubuntu1) ...
# Setting up cuda-nsight-systems-10-1 (10.1.105-1) ...
# Setting up cuda-gdb-10-1 (10.1.105-1) ...
# Setting up cuda-nsight-compute-10-1 (10.1.105-1) ...
# Setting up cuda-cudart-10-1 (10.1.105-1) ...
# Setting up xserver-xorg-input-all (1:7.7+19ubuntu7.1) ...
# Setting up cuda-npp-dev-10-1 (10.1.105-1) ...
# Setting up xserver-xorg-video-nvidia-418 (418.39-0ubuntu1) ...
# Setting up libnvidia-decode-418:amd64 (418.39-0ubuntu1) ...
# Setting up cuda-cusolver-10-1 (10.1.105-1) ...
# Setting up cuda-misc-headers-10-1 (10.1.105-1) ...
# Setting up cuda-nvtx-10-1 (10.1.105-1) ...
# Setting up cuda-curand-10-1 (10.1.105-1) ...
# Setting up cuda-cusparse-dev-10-1 (10.1.105-1) ...
# Setting up cuda-gpu-library-advisor-10-1 (10.1.105-1) ...
# Setting up cuda-nvgraph-10-1 (10.1.105-1) ...
# Setting up cuda-nvprune-10-1 (10.1.105-1) ...
# Setting up cuda-memcheck-10-1 (10.1.105-1) ...
# Setting up cuda-cudart-dev-10-1 (10.1.105-1) ...
# Setting up cuda-nvrtc-dev-10-1 (10.1.105-1) ...
# Setting up cuda-curand-dev-10-1 (10.1.105-1) ...
# Setting up cuda-cusolver-dev-10-1 (10.1.105-1) ...
# Setting up cuda-nvgraph-dev-10-1 (10.1.105-1) ...
# Setting up libnvidia-encode-418:amd64 (418.39-0ubuntu1) ...
# Setting up cuda-libraries-10-1 (10.1.105-1) ...
# Setting up cuda-nvcc-10-1 (10.1.105-1) ...
# Setting up nvidia-driver-418 (418.39-0ubuntu1) ...
# Setting up cuda-compiler-10-1 (10.1.105-1) ...
# Setting up cuda-drivers (418.39-1) ...
# Setting up cuda-visual-tools-10-1 (10.1.105-1) ...
# Setting up cuda-libraries-dev-10-1 (10.1.105-1) ...
# Setting up cuda-samples-10-1 (10.1.105-1) ...
# Setting up cuda-cupti-10-1 (10.1.105-1) ...
# Setting up cuda-documentation-10-1 (10.1.105-1) ...
# Setting up cuda-runtime-10-1 (10.1.105-1) ...
# Setting up cuda-command-line-tools-10-1 (10.1.105-1) ...
# Setting up cuda-demo-suite-10-1 (10.1.105-1) ...
# Setting up cuda-tools-10-1 (10.1.105-1) ...
# Setting up cuda-toolkit-10-1 (10.1.105-1) ...
# Setting up cuda-10-1 (10.1.105-1) ...
# Setting up cuda (10.1.105-1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# Get:1 file:/var/cuda-repo-8-0-local-ga2  InRelease
# Ign:1 file:/var/cuda-repo-8-0-local-ga2  InRelease
# Get:2 file:/var/cuda-repo-8-0-local-ga2  Release [574 B]
# Get:2 file:/var/cuda-repo-8-0-local-ga2  Release [574 B]
# Hit:3 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ InRelease
# Ign:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:5 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:7 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Ign:8 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:10 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:11 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:12 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:13 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic InRelease
# Get:14 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Fetched 252 kB in 2s (145 kB/s)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 16 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Calculating upgrade... Done
# The following packages were automatically installed and are no longer required:
#   cuda-10-0 cuda-demo-suite-10-0 cuda-documentation-10-0 cuda-nsight-10-0
#   cuda-nsight-compute-10-0 cuda-nvvp-10-0 cuda-runtime-10-0 cuda-samples-10-0
#   cuda-toolkit-10-0 cuda-tools-10-0 cuda-visual-tools-10-0
#   libnvidia-common-410
# Use 'apt autoremove' to remove them.
# The following packages have been kept back:
#   libcudnn7 libcudnn7-dev libnccl-dev libnccl2
# The following packages will be upgraded:
#   cuda-compat-10-0 gtk-update-icon-cache libgd3 libgtk-3-0 libgtk-3-common
#   libnss3 libnvidia-common-410 libssl1.0.0 libxnvctrl0 r-cran-openssl
#   r-cran-sys r-cran-tidyr
# 12 upgraded, 0 newly installed, 0 to remove and 4 not upgraded.
# Need to get 12.6 MB of archives.
# After this operation, 9,216 B of additional disk space will be used.
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-compat-10-0 410.104-1 [6,467 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libssl1.0.0 amd64 1.0.2n-1ubuntu5.3 [1,088 kB]
# Get:3 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 r-cran-openssl amd64 1.2.2-1cran1ppabionic0 [571 kB]
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  libnvidia-common-410 410.104-0ubuntu1 [9,804 B]
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  libxnvctrl0 418.39-0ubuntu1 [19.3 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gtk-update-icon-cache amd64 3.22.30-1ubuntu2 [28.1 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgd3 amd64 2.2.5-4ubuntu0.3 [119 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgtk-3-common all 3.22.30-1ubuntu2 [228 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgtk-3-0 amd64 3.22.30-1ubuntu2 [2,500 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libnss3 amd64 2:3.35-2ubuntu2.2 [1,134 kB]
# Get:11 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 r-cran-sys amd64 3.0-1cran1ppabionic0 [38.5 kB]
# Get:12 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 r-cran-tidyr amd64 0.8.3-1cran1ppabionic0 [414 kB]
# Fetched 12.6 MB in 3s (4,048 kB/s)
# Preconfiguring packages ...
# (Reading database ... 148273 files and directories currently installed.)
# Preparing to unpack .../00-libssl1.0.0_1.0.2n-1ubuntu5.3_amd64.deb ...
# Unpacking libssl1.0.0:amd64 (1.0.2n-1ubuntu5.3) over (1.0.2n-1ubuntu5.2) ...
# Preparing to unpack .../01-cuda-compat-10-0_410.104-1_amd64.deb ...
# Unpacking cuda-compat-10-0 (410.104-1) over (410.79-1) ...
# Preparing to unpack .../02-gtk-update-icon-cache_3.22.30-1ubuntu2_amd64.deb ...
# Unpacking gtk-update-icon-cache (3.22.30-1ubuntu2) over (3.22.30-1ubuntu1) ...
# Preparing to unpack .../03-libgd3_2.2.5-4ubuntu0.3_amd64.deb ...
# Unpacking libgd3:amd64 (2.2.5-4ubuntu0.3) over (2.2.5-4ubuntu0.2) ...
# Preparing to unpack .../04-libgtk-3-common_3.22.30-1ubuntu2_all.deb ...
# Unpacking libgtk-3-common (3.22.30-1ubuntu2) over (3.22.30-1ubuntu1) ...
# Preparing to unpack .../05-libgtk-3-0_3.22.30-1ubuntu2_amd64.deb ...
# Unpacking libgtk-3-0:amd64 (3.22.30-1ubuntu2) over (3.22.30-1ubuntu1) ...
# Preparing to unpack .../06-libnss3_2%3a3.35-2ubuntu2.2_amd64.deb ...
# Unpacking libnss3:amd64 (2:3.35-2ubuntu2.2) over (2:3.35-2ubuntu2.1) ...
# Preparing to unpack .../07-libnvidia-common-410_410.104-0ubuntu1_all.deb ...
# Unpacking libnvidia-common-410 (410.104-0ubuntu1) over (410.79-0ubuntu1) ...
# Preparing to unpack .../08-libxnvctrl0_418.39-0ubuntu1_amd64.deb ...
# Unpacking libxnvctrl0:amd64 (418.39-0ubuntu1) over (415.27-0ubuntu0~gpu18.04.1) ...
# Preparing to unpack .../09-r-cran-openssl_1.2.2-1cran1ppabionic0_amd64.deb ...
# Unpacking r-cran-openssl (1.2.2-1cran1ppabionic0) over (1.2.1-1cran1ppabionic0) ...
# Preparing to unpack .../10-r-cran-sys_3.0-1cran1ppabionic0_amd64.deb ...
# Unpacking r-cran-sys (3.0-1cran1ppabionic0) over (2.1-1cran1ppabionic0) ...
# Preparing to unpack .../11-r-cran-tidyr_0.8.3-1cran1ppabionic0_amd64.deb ...
# Unpacking r-cran-tidyr (0.8.3-1cran1ppabionic0) over (0.8.2-1cran1ppabionic0) ...
# Setting up r-cran-openssl (1.2.2-1cran1ppabionic0) ...
# Setting up libssl1.0.0:amd64 (1.0.2n-1ubuntu5.3) ...
# Setting up libgtk-3-common (3.22.30-1ubuntu2) ...
# Processing triggers for libglib2.0-0:amd64 (2.56.3-0ubuntu0.18.04.1) ...
# Setting up r-cran-tidyr (0.8.3-1cran1ppabionic0) ...
# Setting up libgd3:amd64 (2.2.5-4ubuntu0.3) ...
# Setting up libnss3:amd64 (2:3.35-2ubuntu2.2) ...
# Setting up libgtk-3-0:amd64 (3.22.30-1ubuntu2) ...
# Setting up gtk-update-icon-cache (3.22.30-1ubuntu2) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# Setting up libnvidia-common-410 (410.104-0ubuntu1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Setting up r-cran-sys (3.0-1cran1ppabionic0) ...
# Setting up libxnvctrl0:amd64 (418.39-0ubuntu1) ...
# Setting up cuda-compat-10-0 (410.104-1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Note, selecting 'cuda-8-0' for regex 'cuda-8.0'
# Note, selecting 'libcuda-8.0-1' for regex 'cuda-8.0'
# The following packages were automatically installed and are no longer required:
#   cuda-10-0 cuda-demo-suite-10-0 cuda-documentation-10-0 cuda-nsight-10-0
#   cuda-nsight-compute-10-0 cuda-nvvp-10-0 cuda-runtime-10-0 cuda-samples-10-0
#   cuda-toolkit-10-0 cuda-tools-10-0 cuda-visual-tools-10-0
#   libnvidia-common-410
# Use 'apt autoremove' to remove them.
# The following additional packages will be installed:
#   cuda-command-line-tools-8-0 cuda-core-8-0 cuda-cublas-8-0
#   cuda-cublas-dev-8-0 cuda-cudart-8-0 cuda-cudart-dev-8-0 cuda-cufft-8-0
#   cuda-cufft-dev-8-0 cuda-curand-8-0 cuda-curand-dev-8-0 cuda-cusolver-8-0
#   cuda-cusolver-dev-8-0 cuda-cusparse-8-0 cuda-cusparse-dev-8-0
#   cuda-demo-suite-8-0 cuda-documentation-8-0 cuda-driver-dev-8-0
#   cuda-license-8-0 cuda-misc-headers-8-0 cuda-npp-8-0 cuda-npp-dev-8-0
#   cuda-nvgraph-8-0 cuda-nvgraph-dev-8-0 cuda-nvml-dev-8-0 cuda-nvrtc-8-0
#   cuda-nvrtc-dev-8-0 cuda-runtime-8-0 cuda-samples-8-0 cuda-toolkit-8-0
#   cuda-visual-tools-8-0
# The following NEW packages will be installed:
#   cuda-8-0 cuda-command-line-tools-8-0 cuda-core-8-0 cuda-cublas-8-0
#   cuda-cublas-dev-8-0 cuda-cudart-8-0 cuda-cudart-dev-8-0 cuda-cufft-8-0
#   cuda-cufft-dev-8-0 cuda-curand-8-0 cuda-curand-dev-8-0 cuda-cusolver-8-0
#   cuda-cusolver-dev-8-0 cuda-cusparse-8-0 cuda-cusparse-dev-8-0
#   cuda-demo-suite-8-0 cuda-documentation-8-0 cuda-driver-dev-8-0
#   cuda-license-8-0 cuda-misc-headers-8-0 cuda-npp-8-0 cuda-npp-dev-8-0
#   cuda-nvgraph-8-0 cuda-nvgraph-dev-8-0 cuda-nvml-dev-8-0 cuda-nvrtc-8-0
#   cuda-nvrtc-dev-8-0 cuda-runtime-8-0 cuda-samples-8-0 cuda-toolkit-8-0
#   cuda-visual-tools-8-0
# 0 upgraded, 31 newly installed, 0 to remove and 4 not upgraded.
# Need to get 0 B/1,312 MB of archives.
# After this operation, 2,079 MB of additional disk space will be used.
# Get:1 file:/var/cuda-repo-8-0-local-ga2  cuda-license-8-0 8.0.61-1 [27.6 kB]
# Get:2 file:/var/cuda-repo-8-0-local-ga2  cuda-misc-headers-8-0 8.0.61-1 [1,077 kB]
# Get:3 file:/var/cuda-repo-8-0-local-ga2  cuda-core-8-0 8.0.61-1 [20.0 MB]
# Get:4 file:/var/cuda-repo-8-0-local-ga2  cuda-cudart-8-0 8.0.61-1 [135 kB]
# Get:5 file:/var/cuda-repo-8-0-local-ga2  cuda-driver-dev-8-0 8.0.61-1 [14.1 kB]
# Get:6 file:/var/cuda-repo-8-0-local-ga2  cuda-cudart-dev-8-0 8.0.61-1 [1,071 kB]
# Get:7 file:/var/cuda-repo-8-0-local-ga2  cuda-command-line-tools-8-0 8.0.61-1 [26.1 MB]
# Get:8 file:/var/cuda-repo-8-0-local-ga2  cuda-nvrtc-8-0 8.0.61-1 [9,585 kB]
# Get:9 file:/var/cuda-repo-8-0-local-ga2  cuda-nvrtc-dev-8-0 8.0.61-1 [10.8 kB]
# Get:10 file:/var/cuda-repo-8-0-local-ga2  cuda-cusolver-8-0 8.0.61-1 [29.3 MB]
# Get:11 file:/var/cuda-repo-8-0-local-ga2  cuda-cusolver-dev-8-0 8.0.61-1 [6,816 kB]
# Get:12 file:/var/cuda-repo-8-0-local-ga2  cuda-cublas-8-0 8.0.61-1 [27.2 MB]
# Get:13 file:/var/cuda-repo-8-0-local-ga2  cuda-cublas-dev-8-0 8.0.61-1 [57.4 MB]
# Get:14 file:/var/cuda-repo-8-0-local-ga2  cuda-cufft-8-0 8.0.61-1 [117 MB]
# Get:15 file:/var/cuda-repo-8-0-local-ga2  cuda-cufft-dev-8-0 8.0.61-1 [94.8 MB]
# Get:16 file:/var/cuda-repo-8-0-local-ga2  cuda-curand-8-0 8.0.61-1 [43.7 MB]
# Get:17 file:/var/cuda-repo-8-0-local-ga2  cuda-curand-dev-8-0 8.0.61-1 [67.7 MB]
# Get:18 file:/var/cuda-repo-8-0-local-ga2  cuda-cusparse-8-0 8.0.61-1 [28.8 MB]
# Get:19 file:/var/cuda-repo-8-0-local-ga2  cuda-cusparse-dev-8-0 8.0.61-1 [29.6 MB]
# Get:20 file:/var/cuda-repo-8-0-local-ga2  cuda-npp-8-0 8.0.61-1 [157 MB]
# Get:21 file:/var/cuda-repo-8-0-local-ga2  cuda-npp-dev-8-0 8.0.61-1 [82.3 MB]
# Get:22 file:/var/cuda-repo-8-0-local-ga2  cuda-samples-8-0 8.0.61-1 [101 MB]
# Get:23 file:/var/cuda-repo-8-0-local-ga2  cuda-documentation-8-0 8.0.61-1 [113 MB]
# Get:24 file:/var/cuda-repo-8-0-local-ga2  cuda-nvml-dev-8-0 8.0.61-1 [48.4 kB]
# Get:25 file:/var/cuda-repo-8-0-local-ga2  cuda-nvgraph-8-0 8.0.61-1 [2,948 kB]
# Get:26 file:/var/cuda-repo-8-0-local-ga2  cuda-nvgraph-dev-8-0 8.0.61-1 [3,028 kB]
# Get:27 file:/var/cuda-repo-8-0-local-ga2  cuda-visual-tools-8-0 8.0.61-1 [286 MB]
# Get:28 file:/var/cuda-repo-8-0-local-ga2  cuda-toolkit-8-0 8.0.61-1 [2,892 B]
# Get:29 file:/var/cuda-repo-8-0-local-ga2  cuda-runtime-8-0 8.0.61-1 [2,574 B]
# Get:30 file:/var/cuda-repo-8-0-local-ga2  cuda-demo-suite-8-0 8.0.61-1 [4,988 kB]
# Get:31 file:/var/cuda-repo-8-0-local-ga2  cuda-8-0 8.0.61-1 [2,556 B]
# Extracting templates from packages: 100%
# Selecting previously unselected package cuda-license-8-0.
# (Reading database ... 148273 files and directories currently installed.)
# Preparing to unpack .../00-cuda-license-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-license-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-misc-headers-8-0.
# Preparing to unpack .../01-cuda-misc-headers-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-misc-headers-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-core-8-0.
# Preparing to unpack .../02-cuda-core-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-core-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-cudart-8-0.
# Preparing to unpack .../03-cuda-cudart-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-cudart-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-driver-dev-8-0.
# Preparing to unpack .../04-cuda-driver-dev-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-driver-dev-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-cudart-dev-8-0.
# Preparing to unpack .../05-cuda-cudart-dev-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-cudart-dev-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-command-line-tools-8-0.
# Preparing to unpack .../06-cuda-command-line-tools-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-command-line-tools-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-nvrtc-8-0.
# Preparing to unpack .../07-cuda-nvrtc-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-nvrtc-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-nvrtc-dev-8-0.
# Preparing to unpack .../08-cuda-nvrtc-dev-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-nvrtc-dev-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-cusolver-8-0.
# Preparing to unpack .../09-cuda-cusolver-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-cusolver-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-cusolver-dev-8-0.
# Preparing to unpack .../10-cuda-cusolver-dev-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-cusolver-dev-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-cublas-8-0.
# Preparing to unpack .../11-cuda-cublas-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-cublas-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-cublas-dev-8-0.
# Preparing to unpack .../12-cuda-cublas-dev-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-cublas-dev-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-cufft-8-0.
# Preparing to unpack .../13-cuda-cufft-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-cufft-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-cufft-dev-8-0.
# Preparing to unpack .../14-cuda-cufft-dev-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-cufft-dev-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-curand-8-0.
# Preparing to unpack .../15-cuda-curand-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-curand-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-curand-dev-8-0.
# Preparing to unpack .../16-cuda-curand-dev-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-curand-dev-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-cusparse-8-0.
# Preparing to unpack .../17-cuda-cusparse-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-cusparse-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-cusparse-dev-8-0.
# Preparing to unpack .../18-cuda-cusparse-dev-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-cusparse-dev-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-npp-8-0.
# Preparing to unpack .../19-cuda-npp-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-npp-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-npp-dev-8-0.
# Preparing to unpack .../20-cuda-npp-dev-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-npp-dev-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-samples-8-0.
# Preparing to unpack .../21-cuda-samples-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-samples-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-documentation-8-0.
# Preparing to unpack .../22-cuda-documentation-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-documentation-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-nvml-dev-8-0.
# Preparing to unpack .../23-cuda-nvml-dev-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-nvml-dev-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-nvgraph-8-0.
# Preparing to unpack .../24-cuda-nvgraph-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-nvgraph-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-nvgraph-dev-8-0.
# Preparing to unpack .../25-cuda-nvgraph-dev-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-nvgraph-dev-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-visual-tools-8-0.
# Preparing to unpack .../26-cuda-visual-tools-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-visual-tools-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-toolkit-8-0.
# Preparing to unpack .../27-cuda-toolkit-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-toolkit-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-runtime-8-0.
# Preparing to unpack .../28-cuda-runtime-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-runtime-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-demo-suite-8-0.
# Preparing to unpack .../29-cuda-demo-suite-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-demo-suite-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-8-0.
# Preparing to unpack .../30-cuda-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-8-0 (8.0.61-1) ...
# Setting up cuda-license-8-0 (8.0.61-1) ...
# *** LICENSE AGREEMENT ***
# By using this software you agree to fully comply with the terms and
# conditions of the EULA (End User License Agreement). The EULA is located
# at /usr/local/cuda-8.0/doc/EULA.txt. The EULA can also be found at
# http://docs.nvidia.com/cuda/eula/index.html. If you do not agree to the
# terms and conditions of the EULA, do not use the software.
#
# Setting up cuda-nvgraph-8-0 (8.0.61-1) ...
# Setting up cuda-cufft-8-0 (8.0.61-1) ...
# Setting up cuda-npp-8-0 (8.0.61-1) ...
# Setting up cuda-nvgraph-dev-8-0 (8.0.61-1) ...
# Setting up cuda-cudart-8-0 (8.0.61-1) ...
# Setting up cuda-driver-dev-8-0 (8.0.61-1) ...
# Setting up cuda-cusolver-8-0 (8.0.61-1) ...
# Setting up cuda-nvml-dev-8-0 (8.0.61-1) ...
# Setting up cuda-cufft-dev-8-0 (8.0.61-1) ...
# Setting up cuda-misc-headers-8-0 (8.0.61-1) ...
# Setting up cuda-cusparse-8-0 (8.0.61-1) ...
# Setting up cuda-nvrtc-8-0 (8.0.61-1) ...
# Setting up cuda-nvrtc-dev-8-0 (8.0.61-1) ...
# Setting up cuda-curand-8-0 (8.0.61-1) ...
# Setting up cuda-cublas-8-0 (8.0.61-1) ...
# Setting up cuda-cusolver-dev-8-0 (8.0.61-1) ...
# Setting up cuda-core-8-0 (8.0.61-1) ...
# Setting up cuda-curand-dev-8-0 (8.0.61-1) ...
# Setting up cuda-npp-dev-8-0 (8.0.61-1) ...
# Setting up cuda-cudart-dev-8-0 (8.0.61-1) ...
# Setting up cuda-cublas-dev-8-0 (8.0.61-1) ...
# Setting up cuda-runtime-8-0 (8.0.61-1) ...
# Setting up cuda-cusparse-dev-8-0 (8.0.61-1) ...
# Setting up cuda-command-line-tools-8-0 (8.0.61-1) ...
# Setting up cuda-demo-suite-8-0 (8.0.61-1) ...
# Setting up cuda-samples-8-0 (8.0.61-1) ...
# Setting up cuda-visual-tools-8-0 (8.0.61-1) ...
# Setting up cuda-documentation-8-0 (8.0.61-1) ...
# Setting up cuda-toolkit-8-0 (8.0.61-1) ...
# Setting up cuda-8-0 (8.0.61-1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...

# %%
import tensorflow as tf
device_name = tf.test.gpu_device_name()
print(device_name)

print("'sup!'")

# !/usr/local/cuda/bin/nvcc --version
# Out:
# /device:GPU:0
# 'sup!'
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2016 NVIDIA Corporation
# Built on Tue_Jan_10_13:22:03_CST_2017
# Cuda compilation tools, release 8.0, V8.0.61

# %%
# %cd darknet
# !make
# Out:
# /content/darknet
# mkdir -p obj
# mkdir -p backup
# mkdir -p results
# chmod +x *.sh
# g++ -std=c++11 -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/http_stream.cpp -o obj/http_stream.o
# In file included from ./src/http_stream.cpp:49:0:
# ./src/darkunistd.h:24:91: warning: "/*" within comment [-Wcomment]
# ./src/http_stream.cpp: In member function ‘bool MJPG_sender::write(const cv::Mat&)’:
# ./src/http_stream.cpp:259:23: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#                  if (n < outlen)
#                        ^
# ./src/http_stream.cpp: In member function ‘void JSON_sender::close_all()’:
# ./src/http_stream.cpp:333:20: warning: ISO C++ forbids converting a string constant to ‘char*’ [-Wwrite-strings]
#          write("\n]");   // close JSON array
#                     ^
# ./src/http_stream.cpp: In member function ‘bool JSON_sender::write(char*)’:
# ./src/http_stream.cpp:425:21: warning: unused variable ‘n’ [-Wunused-variable]
#                  int n = _write(client, outputbuf, outlen);
#                      ^
# ./src/http_stream.cpp:439:23: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#                  if (n < outlen)
#                        ^
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/gemm.c -o obj/gemm.o
# ./src/gemm.c: In function ‘transpose_32x32_bits_my’:
# ./src/gemm.c:324:20: warning: unused variable ‘t’ [-Wunused-variable]
#      unsigned x, y, t;
#                     ^
# ./src/gemm.c: In function ‘convolution_2d’:
# ./src/gemm.c:2016:15: warning: unused variable ‘out_w’ [-Wunused-variable]
#      const int out_w = (w + 2 * pad - ksize) / stride + 1;    // output_width=input_width for stride=1 and pad=1
#                ^
# ./src/gemm.c:2015:15: warning: unused variable ‘out_h’ [-Wunused-variable]
#      const int out_h = (h + 2 * pad - ksize) / stride + 1;    // output_height=input_height for stride=1 and pad=1
#                ^
# ./src/gemm.c: In function ‘convolution_repacked’:
# ./src/gemm.c:2516:19: warning: unused variable ‘c_pack’ [-Wunused-variable]
#          int chan, c_pack, y, x, f_y, f_x;
#                    ^
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/utils.c -o obj/utils.o
# In file included from ./src/utils.c:12:0:
# ./src/darkunistd.h:24:91: warning: "/*" within comment [-Wcomment]
# ./src/utils.c: In function ‘rand_uniform’:
# ./src/utils.c:760:36: warning: integer overflow in expression [-Woverflow]
#          int rnd = rand()*(RAND_MAX + 1) + rand();
#                                     ^
# ./src/utils.c:761:39: warning: integer overflow in expression [-Woverflow]
#          return ((float)rnd / (RAND_MAX*RAND_MAX) * (max - min)) + min;
#                                        ^
# ./src/utils.c: In function ‘random_gen’:
# ./src/utils.c:796:32: warning: integer overflow in expression [-Woverflow]
#          rnd = rand()*(RAND_MAX + 1) + rnd;
#                                 ^
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/cuda.c -o obj/cuda.o
# ./src/cuda.c: In function ‘get_cuda_stream’:
# ./src/cuda.c:98:18: warning: unused variable ‘buffer’ [-Wunused-variable]
#              char buffer[256];
#                   ^
# ./src/cuda.c: In function ‘get_cuda_memcpy_stream’:
# ./src/cuda.c:119:18: warning: unused variable ‘buffer’ [-Wunused-variable]
#              char buffer[256];
#                   ^
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/convolutional_layer.c -o obj/convolutional_layer.o
# ./src/convolutional_layer.c: In function ‘bit_to_float’:
# ./src/convolutional_layer.c:688:23: warning: unused variable ‘src_shift’ [-Wunused-variable]
#      size_t i,  src_i, src_shift;
#                        ^
# ./src/convolutional_layer.c:688:16: warning: unused variable ‘src_i’ [-Wunused-variable]
#      size_t i,  src_i, src_shift;
#                 ^
# ./src/convolutional_layer.c: In function ‘binary_align_weights’:
# ./src/convolutional_layer.c:735:30: warning: unused variable ‘val’ [-Wunused-variable]
#                      uint32_t val = 0;
#                               ^
# ./src/convolutional_layer.c:759:17: warning: unused variable ‘N’ [-Wunused-variable]
#              int N = l->out_w*l->out_h;
#                  ^
# ./src/convolutional_layer.c:758:17: warning: unused variable ‘M’ [-Wunused-variable]
#              int M = l->n;
#                  ^
# ./src/convolutional_layer.c: In function ‘binary_transpose_align_input’:
# ./src/convolutional_layer.c:815:9: warning: unused variable ‘src_size’ [-Wunused-variable]
#      int src_size = k * bit_align;
#          ^
# ./src/convolutional_layer.c: In function ‘forward_convolutional_layer’:
# ./src/convolutional_layer.c:872:24: warning: unused variable ‘t_bit_input_size’ [-Wunused-variable]
#                  size_t t_bit_input_size = t_intput_size / 8;// +1;
#                         ^
# ./src/convolutional_layer.c:956:28: warning: unused variable ‘t_intput_size’ [-Wunused-variable]
#                      size_t t_intput_size = binary_transpose_align_input(k, n, state.workspace, &l.t_bit_input, ldb_align, l.bit_align);
#                             ^
# ./src/convolutional_layer.c:947:24: warning: unused variable ‘bit_weights_size’ [-Wunused-variable]
#                  size_t bit_weights_size = weights_size / 8 + 1;
#                         ^
# ./src/convolutional_layer.c:943:24: warning: unused variable ‘bit_input_size’ [-Wunused-variable]
#                  size_t bit_input_size = intput_size / 8 + 1;
#                         ^
# ./src/convolutional_layer.c:937:24: warning: unused variable ‘output_size’ [-Wunused-variable]
#                  size_t output_size = l.outputs;
#                         ^
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/list.c -o obj/list.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/image.c -o obj/image.o
# ./src/image.c: In function ‘draw_detections_cv_v3’:
# ./src/image.c:564:19: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#              float rgb[3];
#                    ^
# ./src/image.c: In function ‘draw_detections_cv’:
# ./src/image.c:670:19: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#              float rgb[3];
#                    ^
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/activations.c -o obj/activations.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/im2col.c -o obj/im2col.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/col2im.c -o obj/col2im.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/blas.c -o obj/blas.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/crop_layer.c -o obj/crop_layer.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/dropout_layer.c -o obj/dropout_layer.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/maxpool_layer.c -o obj/maxpool_layer.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/softmax_layer.c -o obj/softmax_layer.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/data.c -o obj/data.o
# ./src/data.c:758:12: warning: ‘float_to_box_stride’ defined but not used [-Wunused-function]
#  static box float_to_box_stride(float *f, int stride)
#             ^
# ./src/data.c: In function ‘load_data_detection’:
# ./src/data.c:794:29: warning: ‘flip’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#      float dhue, dsat, dexp, flip;
#                              ^
# ./src/data.c:849:15: warning: ‘dexp’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#          image ai = image_data_augmentation(src, w, h, pleft, ptop, swidth, sheight, flip, jitter, dhue, dsat, dexp);
#                ^
# ./src/data.c:849:15: warning: ‘dsat’ may be used uninitialized in this function [-Wmaybe-uninitialized]
# ./src/data.c:849:15: warning: ‘dhue’ may be used uninitialized in this function [-Wmaybe-uninitialized]
# ./src/data.c:838:22: warning: ‘r4’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#          int pbot   = rand_precalc_random(-dh, dh, r4);
#                       ^
# ./src/data.c:837:22: warning: ‘r3’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#          int ptop   = rand_precalc_random(-dh, dh, r3);
#                       ^
# ./src/data.c:836:22: warning: ‘r2’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#          int pright = rand_precalc_random(-dw, dw, r2);
#                       ^
# ./src/data.c:835:22: warning: ‘r1’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#          int pleft  = rand_precalc_random(-dw, dw, r1);
#                       ^
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/matrix.c -o obj/matrix.o
# ./src/matrix.c: In function ‘random_centers’:
# ./src/matrix.c:260:12: warning: unused variable ‘j’ [-Wunused-variable]
#      int i, j;
#             ^
# ./src/matrix.c: In function ‘dist’:
# ./src/matrix.c:284:9: warning: unused variable ‘i’ [-Wunused-variable]
#      int i;
#          ^
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/network.c -o obj/network.o
# ./src/network.c: In function ‘resize_network’:
# ./src/network.c:497:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess == cudaHostAlloc(&net->input_pinned_cpu, size * sizeof(float), cudaHostRegisterMapped))
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:91:0,
#                  from include/darknet.h:36,
#                  from ./src/network.c:4:
# /usr/local/cuda/include/cuda_runtime_api.h:3316:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^
# ./src/network.c: In function ‘detection_to_json’:
# ./src/network.c:731:27: warning: format ‘%d’ expects argument of type ‘int’, but argument 3 has type ‘long long int’ [-Wformat=]
#          sprintf(send_buf, "{\n \"frame_id\":%d, \n \"filename\":\"%s\", \n \"objects\": [ \n", frame_id, filename);
#                            ^
# ./src/network.c:734:27: warning: format ‘%d’ expects argument of type ‘int’, but argument 3 has type ‘long long int’ [-Wformat=]
#          sprintf(send_buf, "{\n \"frame_id\":%d, \n \"objects\": [ \n", frame_id);
#                            ^
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/connected_layer.c -o obj/connected_layer.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/cost_layer.c -o obj/cost_layer.o
# ./src/cost_layer.c: In function ‘get_cost_string’:
# ./src/cost_layer.c:21:5: warning: enumeration value ‘L1’ not handled in switch [-Wswitch]
#      switch(a){
#      ^
# ./src/cost_layer.c:21:5: warning: enumeration value ‘SEG’ not handled in switch [-Wswitch]
# ./src/cost_layer.c:21:5: warning: enumeration value ‘WGAN’ not handled in switch [-Wswitch]
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/parser.c -o obj/parser.o
# ./src/parser.c: In function ‘parse_network_cfg_custom’:
# ./src/parser.c:870:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess == cudaHostAlloc(&net.input_pinned_cpu, size * sizeof(float), cudaHostRegisterMapped)) net.input_pinned_cpu_flag = 1;
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:91:0,
#                  from include/darknet.h:36,
#                  from ./src/activations.h:3,
#                  from ./src/activation_layer.h:4,
#                  from ./src/parser.c:5:
# /usr/local/cuda/include/cuda_runtime_api.h:3316:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/option_list.c -o obj/option_list.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/darknet.c -o obj/darknet.o
# ./src/darknet.c: In function ‘main’:
# ./src/darknet.c:477:7: warning: unused variable ‘ext_output’ [-Wunused-variable]
#    int ext_output = find_arg(argc, argv, "-ext_output");
#        ^
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/detection_layer.c -o obj/detection_layer.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/captcha.c -o obj/captcha.o
# ./src/captcha.c: In function ‘train_captcha’:
# ./src/captcha.c:88:16: warning: format ‘%d’ expects argument of type ‘int’, but argument 6 has type ‘uint64_t {aka long unsigned int}’ [-Wformat=]
#          printf("%d: %f, %f avg, %lf seconds, %d images\n", i, loss, avg_loss, sec(clock()-time), *net.seen);
#                 ^
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/route_layer.c -o obj/route_layer.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/writing.c -o obj/writing.o
# ./src/writing.c: In function ‘train_writing’:
# ./src/writing.c:72:16: warning: format ‘%d’ expects argument of type ‘int’, but argument 8 has type ‘uint64_t {aka long unsigned int}’ [-Wformat=]
#          printf("%d, %.3f: %f, %f avg, %f rate, %lf seconds, %d images\n", get_current_batch(net), (float)(*net.seen)/N, loss, avg_loss, get_current_rate(net), sec(clock()-time), *net.seen);
#                 ^
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/box.c -o obj/box.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/nightmare.c -o obj/nightmare.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/normalization_layer.c -o obj/normalization_layer.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/avgpool_layer.c -o obj/avgpool_layer.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/coco.c -o obj/coco.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/dice.c -o obj/dice.o
# ./src/dice.c: In function ‘train_dice’:
# ./src/dice.c:36:16: warning: format ‘%d’ expects argument of type ‘int’, but argument 6 has type ‘uint64_t {aka long unsigned int}’ [-Wformat=]
#          printf("%d: %f, %f avg, %lf seconds, %d images\n", i, loss, avg_loss, sec(clock()-time), *net.seen);
#                 ^
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/yolo.c -o obj/yolo.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/detector.c -o obj/detector.o
# ./src/detector.c: In function ‘train_detector’:
# ./src/detector.c:329:27: warning: too many arguments for format [-Wformat-extra-args]
#              sprintf(buff, "%s/%s_last.weights", backup_directory, base, i);
#                            ^
# ./src/detector.c: In function ‘validate_detector_recall’:
# ./src/detector.c:597:11: warning: unused variable ‘l’ [-Wunused-variable]
#      layer l = net.layers[net.n - 1];
#            ^
# ./src/detector.c: In function ‘validate_detector_map’:
# ./src/detector.c:693:15: warning: unused variable ‘valid_images’ [-Wunused-variable]
#          char *valid_images = option_find_str(options, "valid", train_images);
#                ^
# ./src/detector.c:690:9: warning: unused variable ‘initial_batch’ [-Wunused-variable]
#      int initial_batch;
#          ^
# ./src/detector.c:685:10: warning: variable ‘map’ set but not used [-Wunused-but-set-variable]
#      int *map = 0;
#           ^
# ./src/detector.c:678:9: warning: unused variable ‘j’ [-Wunused-variable]
#      int j;
#          ^
# ./src/detector.c: In function ‘calc_anchors’:
# ./src/detector.c:1124:15: warning: unused variable ‘h’ [-Wunused-variable]
#          float h = boxes_data.vals[i][1] = rel_width_height_array[i * 2 + 1];
#                ^
# ./src/detector.c:1123:15: warning: unused variable ‘w’ [-Wunused-variable]
#          float w = boxes_data.vals[i][0] = rel_width_height_array[i * 2];
#                ^
# ./src/detector.c:1162:20: warning: format ‘%d’ expects argument of type ‘int’, but argument 3 has type ‘double’ [-Wformat=]
#              printf(" Wrong label: i = %d, box_w = %d, box_h = %d, anchor_w = %d, anchor_h = %d, iou = %f \n",
#                     ^
# ./src/detector.c:1162:20: warning: format ‘%d’ expects argument of type ‘int’, but argument 4 has type ‘double’ [-Wformat=]
# ./src/detector.c:1162:20: warning: format ‘%d’ expects argument of type ‘int’, but argument 5 has type ‘double’ [-Wformat=]
# ./src/detector.c:1162:20: warning: format ‘%d’ expects argument of type ‘int’, but argument 6 has type ‘double’ [-Wformat=]
# ./src/detector.c: In function ‘test_detector’:
# ./src/detector.c:1279:12: warning: unused variable ‘time’ [-Wunused-variable]
#      double time;
#             ^
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/layer.c -o obj/layer.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/compare.c -o obj/compare.o
# ./src/compare.c: In function ‘train_compare’:
# ./src/compare.c:57:16: warning: format ‘%d’ expects argument of type ‘int’, but argument 6 has type ‘uint64_t {aka long unsigned int}’ [-Wformat=]
#          printf("%.3f: %f, %f avg, %lf seconds, %d images\n", (float)*net.seen/N, loss, avg_loss, sec(clock()-time), *net.seen);
#                 ^
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/classifier.c -o obj/classifier.o
# ./src/classifier.c: In function ‘train_classifier’:
# ./src/classifier.c:180:16: warning: format ‘%d’ expects argument of type ‘int’, but argument 8 has type ‘uint64_t {aka long unsigned int}’ [-Wformat=]
#          printf("%d, %.3f: %f, %f avg, %f rate, %lf seconds, %d images\n", get_current_batch(net), (float)(*net.seen)/ train_images_num, loss, avg_loss, get_current_rate(net), sec(clock()-time), *net.seen);
#                 ^
# ./src/classifier.c:201:27: warning: too many arguments for format [-Wformat-extra-args]
#              sprintf(buff, "%s/%s_last.weights", backup_directory, base, i);
#                            ^
# ./src/classifier.c: In function ‘predict_classifier’:
# ./src/classifier.c:794:9: warning: unused variable ‘size’ [-Wunused-variable]
#      int size = net.w;
#          ^
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/local_layer.c -o obj/local_layer.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/swag.c -o obj/swag.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/shortcut_layer.c -o obj/shortcut_layer.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/activation_layer.c -o obj/activation_layer.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/rnn_layer.c -o obj/rnn_layer.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/gru_layer.c -o obj/gru_layer.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/rnn.c -o obj/rnn.o
# ./src/rnn.c: In function ‘train_char_rnn’:
# ./src/rnn.c:166:12: warning: format ‘%d’ expects argument of type ‘int’, but argument 6 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#      printf("\n batch = %d, steps = %d, streams = %d, subdivisions = %d, text_size = %d \n", batch, steps, streams, net.subdivisions, size);
#             ^
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/rnn_vid.c -o obj/rnn_vid.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/crnn_layer.c -o obj/crnn_layer.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/demo.c -o obj/demo.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/tag.c -o obj/tag.o
# ./src/tag.c: In function ‘train_tag’:
# ./src/tag.c:67:16: warning: format ‘%d’ expects argument of type ‘int’, but argument 8 has type ‘uint64_t {aka long unsigned int}’ [-Wformat=]
#          printf("%d, %.3f: %f, %f avg, %f rate, %lf seconds, %d images\n", get_current_batch(net), (float)(*net.seen)/N, loss, avg_loss, get_current_rate(net), sec(clock()-time), *net.seen);
#                 ^
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/cifar.c -o obj/cifar.o
# ./src/cifar.c: In function ‘train_cifar’:
# ./src/cifar.c:36:16: warning: format ‘%d’ expects argument of type ‘int’, but argument 8 has type ‘uint64_t {aka long unsigned int}’ [-Wformat=]
#          printf("%d, %.3f: %f, %f avg, %f rate, %lf seconds, %d images\n", get_current_batch(net), (float)(*net.seen)/N, loss, avg_loss, get_current_rate(net), sec(clock()-time), *net.seen);
#                 ^
# ./src/cifar.c: In function ‘train_cifar_distill’:
# ./src/cifar.c:92:16: warning: format ‘%d’ expects argument of type ‘int’, but argument 8 has type ‘uint64_t {aka long unsigned int}’ [-Wformat=]
#          printf("%d, %.3f: %f, %f avg, %f rate, %lf seconds, %d images\n", get_current_batch(net), (float)(*net.seen)/N, loss, avg_loss, get_current_rate(net), sec(clock()-time), *net.seen);
#                 ^
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/go.c -o obj/go.o
# ./src/go.c: In function ‘train_go’:
# ./src/go.c:147:16: warning: format ‘%d’ expects argument of type ‘int’, but argument 8 has type ‘uint64_t {aka long unsigned int}’ [-Wformat=]
#          printf("%d, %.3f: %f, %f avg, %f rate, %lf seconds, %d images\n", get_current_batch(net), (float)(*net.seen)/N, loss, avg_loss, get_current_rate(net), sec(clock()-time), *net.seen);
#                 ^
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/batchnorm_layer.c -o obj/batchnorm_layer.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/art.c -o obj/art.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/region_layer.c -o obj/region_layer.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/reorg_layer.c -o obj/reorg_layer.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/reorg_old_layer.c -o obj/reorg_old_layer.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/super.c -o obj/super.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/voxel.c -o obj/voxel.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/tree.c -o obj/tree.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/yolo_layer.c -o obj/yolo_layer.o
# ./src/yolo_layer.c: In function ‘make_yolo_layer’:
# ./src/yolo_layer.c:58:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#      if (cudaSuccess == cudaHostAlloc(&l.output, batch*l.outputs*sizeof(float), cudaHostRegisterMapped)) l.output_pinned = 1;
#                                       ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:91:0,
#                  from include/darknet.h:36,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:3316:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^
# ./src/yolo_layer.c:65:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#      if (cudaSuccess == cudaHostAlloc(&l.delta, batch*l.outputs*sizeof(float), cudaHostRegisterMapped)) l.delta_pinned = 1;
#                                       ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:91:0,
#                  from include/darknet.h:36,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:3316:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^
# ./src/yolo_layer.c: In function ‘resize_yolo_layer’:
# ./src/yolo_layer.c:92:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->output, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:91:0,
#                  from include/darknet.h:36,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:3316:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^
# ./src/yolo_layer.c:101:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->delta, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:91:0,
#                  from include/darknet.h:36,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:3316:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/upsample_layer.c -o obj/upsample_layer.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/lstm_layer.c -o obj/lstm_layer.o
# nvcc  -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU" -c ./src/convolutional_kernels.cu -o obj/convolutional_kernels.o
# ./src/convolutional_kernels.cu(218): warning: variable "t_bit_input_size" was declared but never referenced
#
# ./src/convolutional_kernels.cu(193): warning: variable "status" was declared but never referenced
#
# ./src/convolutional_kernels.cu(194): warning: variable "input_size" was declared but never referenced
#
# ./src/convolutional_kernels.cu(199): warning: variable "a" was declared but never referenced
#
# ./src/convolutional_kernels.cu(204): warning: variable "t_bit_input_size" was declared but never referenced
#
# ./src/convolutional_kernels.cu(218): warning: variable "t_bit_input_size" was declared but never referenced
#
# ./src/convolutional_kernels.cu(193): warning: variable "status" was declared but never referenced
#
# ./src/convolutional_kernels.cu(194): warning: variable "input_size" was declared but never referenced
#
# ./src/convolutional_kernels.cu(199): warning: variable "a" was declared but never referenced
#
# ./src/convolutional_kernels.cu(204): warning: variable "t_bit_input_size" was declared but never referenced
#
# ./src/convolutional_kernels.cu(218): warning: variable "t_bit_input_size" was declared but never referenced
#
# ./src/convolutional_kernels.cu(193): warning: variable "status" was declared but never referenced
#
# ./src/convolutional_kernels.cu(194): warning: variable "input_size" was declared but never referenced
#
# ./src/convolutional_kernels.cu(199): warning: variable "a" was declared but never referenced
#
# ./src/convolutional_kernels.cu(204): warning: variable "t_bit_input_size" was declared but never referenced
#
# ./src/convolutional_kernels.cu(218): warning: variable "t_bit_input_size" was declared but never referenced
#
# ./src/convolutional_kernels.cu(193): warning: variable "status" was declared but never referenced
#
# ./src/convolutional_kernels.cu(194): warning: variable "input_size" was declared but never referenced
#
# ./src/convolutional_kernels.cu(199): warning: variable "a" was declared but never referenced
#
# ./src/convolutional_kernels.cu(204): warning: variable "t_bit_input_size" was declared but never referenced
#
# ./src/convolutional_kernels.cu(218): warning: variable "t_bit_input_size" was declared but never referenced
#
# ./src/convolutional_kernels.cu(193): warning: variable "status" was declared but never referenced
#
# ./src/convolutional_kernels.cu(194): warning: variable "input_size" was declared but never referenced
#
# ./src/convolutional_kernels.cu(199): warning: variable "a" was declared but never referenced
#
# ./src/convolutional_kernels.cu(204): warning: variable "t_bit_input_size" was declared but never referenced
#
# ./src/convolutional_kernels.cu(218): warning: variable "t_bit_input_size" was declared but never referenced
#
# ./src/convolutional_kernels.cu(193): warning: variable "status" was declared but never referenced
#
# ./src/convolutional_kernels.cu(194): warning: variable "input_size" was declared but never referenced
#
# ./src/convolutional_kernels.cu(199): warning: variable "a" was declared but never referenced
#
# ./src/convolutional_kernels.cu(204): warning: variable "t_bit_input_size" was declared but never referenced
#
# nvcc  -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU" -c ./src/activation_kernels.cu -o obj/activation_kernels.o
# nvcc  -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU" -c ./src/im2col_kernels.cu -o obj/im2col_kernels.o
# ./src/im2col_kernels.cu:126:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#                   ^
# ./src/im2col_kernels.cu:1179:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#       ^
# ./src/im2col_kernels.cu(232): warning: variable "tmp_s" was declared but never referenced
#
# ./src/im2col_kernels.cu(233): warning: variable "tmp256_s" was declared but never referenced
#
# ./src/im2col_kernels.cu(418): warning: variable "num_of_warps" was declared but never referenced
#
# ./src/im2col_kernels.cu(649): warning: variable "num_blocks" was declared but never referenced
#
# ./src/im2col_kernels.cu(699): warning: variable "warps_in_height" was declared but never referenced
#
# ./src/im2col_kernels.cu(793): warning: variable "tmp" was declared but never referenced
#
# ./src/im2col_kernels.cu(1597): warning: variable "h" was declared but never referenced
#
# ./src/im2col_kernels.cu(2158): warning: variable "input_index" was declared but never referenced
#
# ./src/im2col_kernels.cu(2159): warning: variable "weights_index" was declared but never referenced
#
# ./src/im2col_kernels.cu(2143): warning: variable "src_index" was declared but never referenced
#
# ./src/im2col_kernels.cu(2144): warning: variable "input_byte" was declared but never referenced
#
# ./src/im2col_kernels.cu(441): warning: function "remove_bit" was declared but never referenced
#
# ./src/im2col_kernels.cu(447): warning: function "set_bit" was declared but never referenced
#
# ./src/im2col_kernels.cu(948): warning: function "broadcast_bit_1_to_64" was declared but never referenced
#
# ./src/im2col_kernels.cu(956): warning: function "xnor_int32" was declared but never referenced
#
# ./src/im2col_kernels.cu(960): warning: function "xnor_int64" was declared but never referenced
#
# ./src/im2col_kernels.cu(964): warning: function "xnor_int128" was declared but never referenced
#
# ./src/im2col_kernels.cu(973): warning: function "xnor_int256" was declared but never referenced
#
# ./src/im2col_kernels.cu(984): warning: function "xor_bit1" was declared but never referenced
#
# ./src/im2col_kernels.cu(996): warning: function "xor_int128" was declared but never referenced
#
# ./src/im2col_kernels.cu(1015): warning: function "popcnt_256" was declared but never referenced
#
# ./src/im2col_kernels.cu:126:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#                   ^
# ./src/im2col_kernels.cu:1179:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#       ^
# ./src/im2col_kernels.cu(232): warning: variable "tmp_s" was declared but never referenced
#
# ./src/im2col_kernels.cu(233): warning: variable "tmp256_s" was declared but never referenced
#
# ./src/im2col_kernels.cu(418): warning: variable "num_of_warps" was declared but never referenced
#
# ./src/im2col_kernels.cu(649): warning: variable "num_blocks" was declared but never referenced
#
# ./src/im2col_kernels.cu(699): warning: variable "warps_in_height" was declared but never referenced
#
# ./src/im2col_kernels.cu(793): warning: variable "tmp" was declared but never referenced
#
# ./src/im2col_kernels.cu(1597): warning: variable "h" was declared but never referenced
#
# ./src/im2col_kernels.cu(2158): warning: variable "input_index" was declared but never referenced
#
# ./src/im2col_kernels.cu(2159): warning: variable "weights_index" was declared but never referenced
#
# ./src/im2col_kernels.cu(2143): warning: variable "src_index" was declared but never referenced
#
# ./src/im2col_kernels.cu(2144): warning: variable "input_byte" was declared but never referenced
#
# ./src/im2col_kernels.cu(441): warning: function "remove_bit" was declared but never referenced
#
# ./src/im2col_kernels.cu(447): warning: function "set_bit" was declared but never referenced
#
# ./src/im2col_kernels.cu(948): warning: function "broadcast_bit_1_to_64" was declared but never referenced
#
# ./src/im2col_kernels.cu(956): warning: function "xnor_int32" was declared but never referenced
#
# ./src/im2col_kernels.cu(960): warning: function "xnor_int64" was declared but never referenced
#
# ./src/im2col_kernels.cu(964): warning: function "xnor_int128" was declared but never referenced
#
# ./src/im2col_kernels.cu(973): warning: function "xnor_int256" was declared but never referenced
#
# ./src/im2col_kernels.cu(984): warning: function "xor_bit1" was declared but never referenced
#
# ./src/im2col_kernels.cu(996): warning: function "xor_int128" was declared but never referenced
#
# ./src/im2col_kernels.cu(1015): warning: function "popcnt_256" was declared but never referenced
#
# ./src/im2col_kernels.cu:126:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#                   ^
# ./src/im2col_kernels.cu:1179:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#       ^
# ./src/im2col_kernels.cu(232): warning: variable "tmp_s" was declared but never referenced
#
# ./src/im2col_kernels.cu(233): warning: variable "tmp256_s" was declared but never referenced
#
# ./src/im2col_kernels.cu(418): warning: variable "num_of_warps" was declared but never referenced
#
# ./src/im2col_kernels.cu(649): warning: variable "num_blocks" was declared but never referenced
#
# ./src/im2col_kernels.cu(699): warning: variable "warps_in_height" was declared but never referenced
#
# ./src/im2col_kernels.cu(793): warning: variable "tmp" was declared but never referenced
#
# ./src/im2col_kernels.cu(1597): warning: variable "h" was declared but never referenced
#
# ./src/im2col_kernels.cu(2158): warning: variable "input_index" was declared but never referenced
#
# ./src/im2col_kernels.cu(2159): warning: variable "weights_index" was declared but never referenced
#
# ./src/im2col_kernels.cu(2143): warning: variable "src_index" was declared but never referenced
#
# ./src/im2col_kernels.cu(2144): warning: variable "input_byte" was declared but never referenced
#
# ./src/im2col_kernels.cu(441): warning: function "remove_bit" was declared but never referenced
#
# ./src/im2col_kernels.cu(447): warning: function "set_bit" was declared but never referenced
#
# ./src/im2col_kernels.cu(948): warning: function "broadcast_bit_1_to_64" was declared but never referenced
#
# ./src/im2col_kernels.cu(956): warning: function "xnor_int32" was declared but never referenced
#
# ./src/im2col_kernels.cu(960): warning: function "xnor_int64" was declared but never referenced
#
# ./src/im2col_kernels.cu(964): warning: function "xnor_int128" was declared but never referenced
#
# ./src/im2col_kernels.cu(973): warning: function "xnor_int256" was declared but never referenced
#
# ./src/im2col_kernels.cu(984): warning: function "xor_bit1" was declared but never referenced
#
# ./src/im2col_kernels.cu(996): warning: function "xor_int128" was declared but never referenced
#
# ./src/im2col_kernels.cu(1015): warning: function "popcnt_256" was declared but never referenced
#
# ./src/im2col_kernels.cu:126:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#                   ^
# ./src/im2col_kernels.cu:1179:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#       ^
# ./src/im2col_kernels.cu(232): warning: variable "tmp_s" was declared but never referenced
#
# ./src/im2col_kernels.cu(233): warning: variable "tmp256_s" was declared but never referenced
#
# ./src/im2col_kernels.cu(418): warning: variable "num_of_warps" was declared but never referenced
#
# ./src/im2col_kernels.cu(649): warning: variable "num_blocks" was declared but never referenced
#
# ./src/im2col_kernels.cu(699): warning: variable "warps_in_height" was declared but never referenced
#
# ./src/im2col_kernels.cu(793): warning: variable "tmp" was declared but never referenced
#
# ./src/im2col_kernels.cu(1597): warning: variable "h" was declared but never referenced
#
# ./src/im2col_kernels.cu(2158): warning: variable "input_index" was declared but never referenced
#
# ./src/im2col_kernels.cu(2159): warning: variable "weights_index" was declared but never referenced
#
# ./src/im2col_kernels.cu(2143): warning: variable "src_index" was declared but never referenced
#
# ./src/im2col_kernels.cu(2144): warning: variable "input_byte" was declared but never referenced
#
# ./src/im2col_kernels.cu(441): warning: function "remove_bit" was declared but never referenced
#
# ./src/im2col_kernels.cu(447): warning: function "set_bit" was declared but never referenced
#
# ./src/im2col_kernels.cu(948): warning: function "broadcast_bit_1_to_64" was declared but never referenced
#
# ./src/im2col_kernels.cu(956): warning: function "xnor_int32" was declared but never referenced
#
# ./src/im2col_kernels.cu(960): warning: function "xnor_int64" was declared but never referenced
#
# ./src/im2col_kernels.cu(964): warning: function "xnor_int128" was declared but never referenced
#
# ./src/im2col_kernels.cu(973): warning: function "xnor_int256" was declared but never referenced
#
# ./src/im2col_kernels.cu(984): warning: function "xor_bit1" was declared but never referenced
#
# ./src/im2col_kernels.cu(996): warning: function "xor_int128" was declared but never referenced
#
# ./src/im2col_kernels.cu(1015): warning: function "popcnt_256" was declared but never referenced
#
# ./src/im2col_kernels.cu:126:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#                   ^
# ./src/im2col_kernels.cu:1179:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#       ^
# ./src/im2col_kernels.cu(232): warning: variable "tmp_s" was declared but never referenced
#
# ./src/im2col_kernels.cu(233): warning: variable "tmp256_s" was declared but never referenced
#
# ./src/im2col_kernels.cu(418): warning: variable "num_of_warps" was declared but never referenced
#
# ./src/im2col_kernels.cu(649): warning: variable "num_blocks" was declared but never referenced
#
# ./src/im2col_kernels.cu(699): warning: variable "warps_in_height" was declared but never referenced
#
# ./src/im2col_kernels.cu(793): warning: variable "tmp" was declared but never referenced
#
# ./src/im2col_kernels.cu(1597): warning: variable "h" was declared but never referenced
#
# ./src/im2col_kernels.cu(2158): warning: variable "input_index" was declared but never referenced
#
# ./src/im2col_kernels.cu(2159): warning: variable "weights_index" was declared but never referenced
#
# ./src/im2col_kernels.cu(2143): warning: variable "src_index" was declared but never referenced
#
# ./src/im2col_kernels.cu(2144): warning: variable "input_byte" was declared but never referenced
#
# ./src/im2col_kernels.cu(441): warning: function "remove_bit" was declared but never referenced
#
# ./src/im2col_kernels.cu(447): warning: function "set_bit" was declared but never referenced
#
# ./src/im2col_kernels.cu(948): warning: function "broadcast_bit_1_to_64" was declared but never referenced
#
# ./src/im2col_kernels.cu(956): warning: function "xnor_int32" was declared but never referenced
#
# ./src/im2col_kernels.cu(960): warning: function "xnor_int64" was declared but never referenced
#
# ./src/im2col_kernels.cu(964): warning: function "xnor_int128" was declared but never referenced
#
# ./src/im2col_kernels.cu(973): warning: function "xnor_int256" was declared but never referenced
#
# ./src/im2col_kernels.cu(984): warning: function "xor_bit1" was declared but never referenced
#
# ./src/im2col_kernels.cu(996): warning: function "xor_int128" was declared but never referenced
#
# ./src/im2col_kernels.cu(1015): warning: function "popcnt_256" was declared but never referenced
#
# ./src/im2col_kernels.cu:126:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#                   ^
# ./src/im2col_kernels.cu:1179:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#       ^
# ./src/im2col_kernels.cu(232): warning: variable "tmp_s" was declared but never referenced
#
# ./src/im2col_kernels.cu(233): warning: variable "tmp256_s" was declared but never referenced
#
# ./src/im2col_kernels.cu(418): warning: variable "num_of_warps" was declared but never referenced
#
# ./src/im2col_kernels.cu(649): warning: variable "num_blocks" was declared but never referenced
#
# ./src/im2col_kernels.cu(699): warning: variable "warps_in_height" was declared but never referenced
#
# ./src/im2col_kernels.cu(793): warning: variable "tmp" was declared but never referenced
#
# ./src/im2col_kernels.cu(1597): warning: variable "h" was declared but never referenced
#
# ./src/im2col_kernels.cu(2158): warning: variable "input_index" was declared but never referenced
#
# ./src/im2col_kernels.cu(2159): warning: variable "weights_index" was declared but never referenced
#
# ./src/im2col_kernels.cu(2143): warning: variable "src_index" was declared but never referenced
#
# ./src/im2col_kernels.cu(2144): warning: variable "input_byte" was declared but never referenced
#
# ./src/im2col_kernels.cu(441): warning: function "remove_bit" was declared but never referenced
#
# ./src/im2col_kernels.cu(447): warning: function "set_bit" was declared but never referenced
#
# ./src/im2col_kernels.cu(948): warning: function "broadcast_bit_1_to_64" was declared but never referenced
#
# ./src/im2col_kernels.cu(956): warning: function "xnor_int32" was declared but never referenced
#
# ./src/im2col_kernels.cu(960): warning: function "xnor_int64" was declared but never referenced
#
# ./src/im2col_kernels.cu(964): warning: function "xnor_int128" was declared but never referenced
#
# ./src/im2col_kernels.cu(973): warning: function "xnor_int256" was declared but never referenced
#
# ./src/im2col_kernels.cu(984): warning: function "xor_bit1" was declared but never referenced
#
# ./src/im2col_kernels.cu(996): warning: function "xor_int128" was declared but never referenced
#
# ./src/im2col_kernels.cu(1015): warning: function "popcnt_256" was declared but never referenced
#
# nvcc  -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU" -c ./src/col2im_kernels.cu -o obj/col2im_kernels.o
# nvcc  -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU" -c ./src/blas_kernels.cu -o obj/blas_kernels.o
# nvcc  -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU" -c ./src/crop_layer_kernels.cu -o obj/crop_layer_kernels.o
# nvcc  -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU" -c ./src/dropout_layer_kernels.cu -o obj/dropout_layer_kernels.o
# nvcc  -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU" -c ./src/maxpool_layer_kernels.cu -o obj/maxpool_layer_kernels.o
# nvcc  -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU" -c ./src/network_kernels.cu -o obj/network_kernels.o
# nvcc  -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU" -c ./src/avgpool_layer_kernels.cu -o obj/avgpool_layer_kernels.o
# g++ -std=c++11 -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU obj/http_stream.o obj/gemm.o obj/utils.o obj/cuda.o obj/convolutional_layer.o obj/list.o obj/image.o obj/activations.o obj/im2col.o obj/col2im.o obj/blas.o obj/crop_layer.o obj/dropout_layer.o obj/maxpool_layer.o obj/softmax_layer.o obj/data.o obj/matrix.o obj/network.o obj/connected_layer.o obj/cost_layer.o obj/parser.o obj/option_list.o obj/darknet.o obj/detection_layer.o obj/captcha.o obj/route_layer.o obj/writing.o obj/box.o obj/nightmare.o obj/normalization_layer.o obj/avgpool_layer.o obj/coco.o obj/dice.o obj/yolo.o obj/detector.o obj/layer.o obj/compare.o obj/classifier.o obj/local_layer.o obj/swag.o obj/shortcut_layer.o obj/activation_layer.o obj/rnn_layer.o obj/gru_layer.o obj/rnn.o obj/rnn_vid.o obj/crnn_layer.o obj/demo.o obj/tag.o obj/cifar.o obj/go.o obj/batchnorm_layer.o obj/art.o obj/region_layer.o obj/reorg_layer.o obj/reorg_old_layer.o obj/super.o obj/voxel.o obj/tree.o obj/yolo_layer.o obj/upsample_layer.o obj/lstm_layer.o obj/convolutional_kernels.o obj/activation_kernels.o obj/im2col_kernels.o obj/col2im_kernels.o obj/blas_kernels.o obj/crop_layer_kernels.o obj/dropout_layer_kernels.o obj/maxpool_layer_kernels.o obj/network_kernels.o obj/avgpool_layer_kernels.o -o darknet -lm -pthread  `pkg-config --libs opencv`  -L/usr/local/cuda/lib64 -lcuda -lcudart -lcublas -lcurand -lstdc++

# %%
# !ls
#Now, let's see if everything works by running it on a test image
# !./darknet detect cfg/yolov3.cfg yolov3.weights data/person.jpg
# Out:
# 3rdparty      CMakeLists.txt	  include		 scripts
# appveyor.yml  CMakeSettings.json  json_mjpeg_streams.sh  src
# backup	      darknet		  LICENSE		 video_v2.sh
# build	      darknet.py	  Makefile		 video_yolov3.sh
# build.ps1     darknet_video.py	  net_cam_v3.sh		 yolov3.weights
# build.sh      data		  obj
# cfg	      image_yolov2.sh	  README.md
# cmake	      image_yolov3.sh	  results
# layer     filters    size              input                output
#    0 conv     32  3 x 3 / 1   416 x 416 x   3   ->   416 x 416 x  32 0.299 BF
#    1 conv     64  3 x 3 / 2   416 x 416 x  32   ->   208 x 208 x  64 1.595 BF
#    2 conv     32  1 x 1 / 1   208 x 208 x  64   ->   208 x 208 x  32 0.177 BF
#    3 conv     64  3 x 3 / 1   208 x 208 x  32   ->   208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1
#    5 conv    128  3 x 3 / 2   208 x 208 x  64   ->   104 x 104 x 128 1.595 BF
#    6 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64 0.177 BF
#    7 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128 1.595 BF
#    8 Shortcut Layer: 5
#    9 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64 0.177 BF
#   10 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128 1.595 BF
#   11 Shortcut Layer: 8
#   12 conv    256  3 x 3 / 2   104 x 104 x 128   ->    52 x  52 x 256 1.595 BF
#   13 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128 0.177 BF
#   14 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#   15 Shortcut Layer: 12
#   16 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128 0.177 BF
#   17 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#   18 Shortcut Layer: 15
#   19 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128 0.177 BF
#   20 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#   21 Shortcut Layer: 18
#   22 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128 0.177 BF
#   23 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#   24 Shortcut Layer: 21
#   25 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128 0.177 BF
#   26 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#   27 Shortcut Layer: 24
#   28 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128 0.177 BF
#   29 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#   30 Shortcut Layer: 27
#   31 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128 0.177 BF
#   32 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#   33 Shortcut Layer: 30
#   34 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128 0.177 BF
#   35 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#   36 Shortcut Layer: 33
#   37 conv    512  3 x 3 / 2    52 x  52 x 256   ->    26 x  26 x 512 1.595 BF
#   38 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256 0.177 BF
#   39 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   40 Shortcut Layer: 37
#   41 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256 0.177 BF
#   42 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   43 Shortcut Layer: 40
#   44 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256 0.177 BF
#   45 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   46 Shortcut Layer: 43
#   47 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256 0.177 BF
#   48 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   49 Shortcut Layer: 46
#   50 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256 0.177 BF
#   51 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   52 Shortcut Layer: 49
#   53 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256 0.177 BF
#   54 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   55 Shortcut Layer: 52
#   56 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256 0.177 BF
#   57 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   58 Shortcut Layer: 55
#   59 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256 0.177 BF
#   60 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   61 Shortcut Layer: 58
#   62 conv   1024  3 x 3 / 2    26 x  26 x 512   ->    13 x  13 x1024 1.595 BF
#   63 conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512 0.177 BF
#   64 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024 1.595 BF
#   65 Shortcut Layer: 62
#   66 conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512 0.177 BF
#   67 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024 1.595 BF
#   68 Shortcut Layer: 65
#   69 conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512 0.177 BF
#   70 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024 1.595 BF
#   71 Shortcut Layer: 68
#   72 conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512 0.177 BF
#   73 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024 1.595 BF
#   74 Shortcut Layer: 71
#   75 conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512 0.177 BF
#   76 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024 1.595 BF
#   77 conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512 0.177 BF
#   78 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024 1.595 BF
#   79 conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512 0.177 BF
#   80 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024 1.595 BF
#   81 conv    255  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 255 0.088 BF
#   82 yolo
#   83 route  79
#   84 conv    256  1 x 1 / 1    13 x  13 x 512   ->    13 x  13 x 256 0.044 BF
#   85 upsample            2x    13 x  13 x 256   ->    26 x  26 x 256
#   86 route  85 61
#   87 conv    256  1 x 1 / 1    26 x  26 x 768   ->    26 x  26 x 256 0.266 BF
#   88 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   89 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256 0.177 BF
#   90 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   91 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256 0.177 BF
#   92 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   93 conv    255  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 255 0.177 BF
#   94 yolo
#   95 route  91
#   96 conv    128  1 x 1 / 1    26 x  26 x 256   ->    26 x  26 x 128 0.044 BF
#   97 upsample            2x    26 x  26 x 128   ->    52 x  52 x 128
#   98 route  97 36
#   99 conv    128  1 x 1 / 1    52 x  52 x 384   ->    52 x  52 x 128 0.266 BF
#  100 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#  101 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128 0.177 BF
#  102 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#  103 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128 0.177 BF
#  104 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#  105 conv    255  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 255 0.353 BF
#  106 yolo
# Total BFLOPS 65.864
#  Allocate additional workspace_size = 49.84 MB
# Loading weights from yolov3.weights...
#  seen 64
# Done!
# data/person.jpg: Predicted in 266.192000 milli-seconds.
# dog: 99%	(left_x:   59   top_y:  262   width:  147   height:   89)
# person: 100%	(left_x:  190   top_y:   95   width:   86   height:  284)
# horse: 100%	(left_x:  394   top_y:  137   width:  215   height:  206)
# Unable to init server: Could not connect: Connection refused
#
# (predictions:16784): Gtk-WARNING **: 10:48:45.074: cannot open display:

# %%
def imShow(path):
  import cv2
  import matplotlib.pyplot as plt
  # %matplotlib inline

  image = cv2.imread(path)
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  #plt.rcParams['figure.figsize'] = [10, 5]
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  plt.show()
  
  
def upload():
  from google.colab import files
  uploaded = files.upload() 
  for name, data in uploaded.items():
    with open(name, 'wb') as f:
      f.write(data)
      print ('saved file', name)
def download(path):
  from google.colab import files
  files.download(path)

# %%
imShow('predictions.jpg')

# %%
# !ls
# Out:
# 3rdparty      CMakeLists.txt	  include		 results
# appveyor.yml  CMakeSettings.json  json_mjpeg_streams.sh  scripts
# backup	      darknet		  LICENSE		 src
# build	      darknet.py	  Makefile		 video_v2.sh
# build.ps1     darknet_video.py	  net_cam_v3.sh		 video_yolov3.sh
# build.sh      data		  obj			 yolov3.weights
# cfg	      image_yolov2.sh	  predictions.jpg
# cmake	      image_yolov3.sh	  README.md

# %%
# !git init
# !git add README.md
# !git commit -m "first commit"
# !git remote add origin https://github.com/hanif9699/yoloml.git
# !git push -u origin master
# Out:
# Reinitialized existing Git repository in /content/darknet/.git/
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@90881546876a.(none)')
# fatal: remote origin already exists.
# fatal: could not read Username for 'https://github.com': No such device or address
